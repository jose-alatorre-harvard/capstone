# %% [markdown]
# <img src="static/img/reminder.jpg">

# %% [markdown]
# # Capstone Project Demonstration
#
#
# In this capstone we explored the usage of Reinforcement Learningfor portfolio construction and enhancement of quantitative investmentstrategies (QIS). Particularly we explored the usage of Policy GradientMethods (PGM) due to their ability to handle continuous action spaces.We used PGM to create a model free agent that selects portfolio weights according to a diverse set of features that we considered as space. The PGM explored are: REINFORCE, REINFORCEwith baseline, Actor-Critic, Actor-Critic with eligibility traces and soft-actor Critic.
#
# Exploring model-free reinforcement leanring algorithms in portfolio allocation that can be generalized to any type of features provides ground work to integrate signal discovery into portfolio allocation.
#
#
# ## Stones on the way ( Problems we faced)
#
# We will focus particularly on the problem that we faced related to the proposed models.
#
# 1. Slow convergence : REINFORCE and REINFORCE with baselines experienced extremely slow convergence in the test set. This make us consider the impracticity of the algorithms for real world solutions where the number of features are complexity of the data require a higher dimensional space.
#
# 2. Complex model pipelines: RL implementation requires more complex model pipelines than other machine learning models due to the necesity of creating different assets likes:environment, actors and policies. The interaction of assets in the algorithm creates a complex relation that is not simple to paralelize or transport to other devices. For example; in Soft Actor Critic, the agent  has a 4 architectures one model for the policy mean one for the policy variance and 2 for a twin Q function. Each of this model is a Neural Network that needs to be trained in synchrony at each step.
#
# 3. Sampling efficiency. As with any reinforcement leanring algorithm, a great amount of time is spent in sampling sars from the environment.
#
# 4. Parametrizing the standard deviation on the normal policy did not seem to bring any improvement as we couldnt achieve learning on this parameter.

# %% [markdown]
# ## Model Test and proper model function
#
# For the control dataset, we simulated different assets using a classical geometric Brownian motion process for each of the assets i.e.
#
# $$
# dS_t=\mu S_tdt+\sqrt{\sigma}S_tdB_t
# $$
#
# The control data set is built to measure the porformance of each model/algorithm against known solutions given a constant drift and a constant volatility.
#
# We measured each algorithm on a 2-asset simulated data using two different reward windows.
#
# 1. Next period return: On each observation the agent gets as reward the return of the portfolio for the next period.
# 2. Negative of squared return : On each observation the agent gets as reward the negative of the squared return of the portfolio in the next period.
#
# With only two assets we expect that our algorithm will converge to the asset with highest return for the next period return reward and to the asset with the smaller volatility in the second reward.

# %% [markdown]
# ### Test Runs
#
# To run test on simulated assets, user just neeed to define a dictionary with the assets characteristics.
# and use the class method 'build_environment_from_simulated_assets' from the Environment class. Below we show the run for REINFORCE and ACTOR_CRITIC.

# %% [markdown]
# <img src="static/img/conver_1.png">

# %% [markdown]
# <img src="static/img/conv2.png">

# %%
from environments.e_greedy import DeepTradingEnvironment, LinearAgent,DeepAgentPytorch
import datetime
import numpy as np


out_reward_window=datetime.timedelta(days=1)
# parameters related to the transformation of data, this parameters govern an step before the algorithm
meta_parameters = {"in_bars_count": 30,
                   "out_reward_window":out_reward_window ,
                   "state_type":"in_window_out_window",
                   "asset_names":["asset_1","asset_2"],
                   "include_previous_weights":False}

# parameters that are related to the objective/reward function construction
objective_parameters = {"percent_commission": .001,
                        }
print("===Meta Parameters===")
print(meta_parameters)
print("===Objective Parameters===")
print(objective_parameters)

assets_simulation_details={"asset_1":{"method":"GBM","sigma":.01,"mean":.02},
                    "asset_2":{"method":"GBM","sigma":.03,"mean":.18}}

env=DeepTradingEnvironment.build_environment_from_simulated_assets(assets_simulation_details=assets_simulation_details,
                                                                     data_hash="simulation_gbm",
                                                                     meta_parameters=meta_parameters,
                                                                     objective_parameters=objective_parameters)
# Out:
# ===Meta Parameters===
# {'in_bars_count': 30, 'out_reward_window': datetime.timedelta(days=1), 'state_type': 'in_window_out_window', 'asset_names': ['asset_1', 'asset_2'], 'include_previous_weights': False}
# ===Objective Parameters===
# {'percent_commission': 0.001}
# /home/jose/venv/p37_deep_trading/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# linear_agent=LinearAgent(environment=env,out_reward_window_td=out_reward_window,
#                          reward_function="cum_return",sample_observations=32)
# linear_agent.REINFORCE_fit(add_baseline=False,max_iterations=4000,plot_every=3999)

# %%
# linear_agent=LinearAgent(environment=env,out_reward_window_td=out_reward_window,
#                          reward_function="cum_return",sample_observations=32)
# linear_agent.REINFORCE_fit(add_baseline=True,max_iterations=4000,plot_every=3999)

# %%
# linear_agent=LinearAgent(environment=env,out_reward_window_td=out_reward_window,
#                          reward_function="cum_return",sample_observations=32)
# linear_agent.ACTOR_CRITIC_FIT(use_traces=True,max_iterations=2001)

# %%
# linear_agent_min_vol=LinearAgent(environment=env,out_reward_window_td=out_reward_window,
#                          reward_function="min_variance",sample_observations=32)
# linear_agent_min_vol.REINFORCE_fit(add_baseline=False,max_iterations=10000,plot_every=3999)

# %%
linear_agent_min_vol=LinearAgent(environment=env,out_reward_window_td=out_reward_window,
                         reward_function="min_vol",sample_observations=32)
linear_agent_min_vol.REINFORCE_fit(add_baseline=True,max_iterations=4000,plot_every=3999)
# Out:
# pre-sampling indices: 100%|██████████| 1373/1373 [00:16<00:00, 83.59it/s]
# 100%|█████████▉| 3998/4000 [06:44<00:00,  9.42it/s]
# 100%|██████████| 4000/4000 [06:45<00:00,  6.60it/s]
# []

# %%
# linear_agent_min_vol=LinearAgent(environment=env,out_reward_window_td=out_reward_window,
#                          reward_function="min_vol",sample_observations=32)
# linear_agent_min_vol.ACTOR_CRITIC_FIT(use_traces=True,max_iterations=4000,plot_every=3999)

# %% [markdown]
# ### Soft Actor Critic.
#
# We separated the execution of Soft actor critic as it uses a third party library.

# %%
from environments.open_ai import DeepTradingEnvironment
from algorithms.sac.sac import sac as sac_capstone
import pandas as pd
from algorithms.sac.core import MLPActorCritic as MLPActorCriticCapstone

# %%
out_reward_window=datetime.timedelta(days=1)
meta_parameters = {"in_bars_count": 30,
                   "out_reward_window":out_reward_window ,
                   "state_type":"in_window_out_window",
                   "asset_names":["asset_1","asset_2"],
                   "include_previous_weights":False}

objective_parameters = {"percent_commission": .001,
                        "reward_function":"min_realized_variance"
                        }
features=pd.read_parquet("/home/jose/code/capstone/temp_persisted_data/only_features_simulation_gbm")
forward_returns_dates=pd.read_parquet("/home/jose/code/capstone/temp_persisted_data/forward_return_dates_simulation_gbm")
forward_returns= pd.read_parquet("/home/jose/code/capstone/temp_persisted_data/only_forward_returns_simulation_gbm")
new_environment= DeepTradingEnvironment(objective_parameters=objective_parameters,meta_parameters=meta_parameters,
                                        features=features,
                                        forward_returns=forward_returns,
                                        forward_returns_dates=forward_returns_dates)



env_fun =lambda : DeepTradingEnvironment(objective_parameters=objective_parameters,meta_parameters=meta_parameters,
                                        features=features,
                                        forward_returns=forward_returns,
                                        forward_returns_dates=forward_returns_dates)



#cum return
sac_capstone(env_fn=env_fun,actor_critic=MLPActorCriticCapstone,ac_kwargs={"hidden_sizes":(1,)},update_every=32,steps_per_epoch=64,epochs=400,
             start_steps=32,update_after=32*5,alpha=.001*0, lr=1e-3,save_freq=10000,num_test_episodes=1
            )
# Out:
# /home/jose/venv/p37_deep_trading/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Logging data to /tmp/experiments/1607280192/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             1
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.0,
#     "batch_size":	100,
#     "env_fn":	"<function <lambda> at 0x7fc2f978fcb0>",
#     "epochs":	400,
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc2fa75d1d0>":	{
#             "epoch_dict":	{},
#             "exp_name":	null,
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/tmp/experiments/1607280192",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/tmp/experiments/1607280192/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{},
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	1,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	10000,
#     "seed":	0,
#     "start_steps":	32,
#     "steps_per_epoch":	64,
#     "update_after":	160,
#     "update_every":	32
# }
#
# Number of parameters: 	 pi: 71, 	 q1: 67, 	 q2: 67
#
# ---------------------------------------
# |           asset_0 |           0.468 |
# |           asset_1 |           0.532 |
# |             Epoch |               3 |
# |      AverageEpRet |       -0.000871 |
# |          StdEpRet |         0.00045 |
# |          MaxEpRet |       -0.000245 |
# |          MinEpRet |        -0.00171 |
# |  AverageTestEpRet |        -0.00147 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -0.00147 |
# |      MinTestEpRet |        -0.00147 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             191 |
# |     AverageQ1Vals |          -0.101 |
# |         StdQ1Vals |         0.00946 |
# |         MaxQ1Vals |         -0.0834 |
# |         MinQ1Vals |          -0.117 |
# |     AverageQ2Vals |          -0.568 |
# |         StdQ2Vals |         0.00695 |
# |         MaxQ2Vals |          -0.558 |
# |         MinQ2Vals |          -0.589 |
# |      AverageLogPi |          -0.174 |
# |          StdLogPi |           0.943 |
# |          MaxLogPi |           0.789 |
# |          MinLogPi |           -8.65 |
# |            LossPi |           0.567 |
# |             LossQ |           0.228 |
# |              Time |           0.717 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.48 |
# |           asset_1 |            0.52 |
# |             Epoch |               4 |
# |      AverageEpRet |        -0.00168 |
# |          StdEpRet |         0.00141 |
# |          MaxEpRet |       -0.000267 |
# |          MinEpRet |        -0.00309 |
# |  AverageTestEpRet |       -1.84e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -1.84e-05 |
# |      MinTestEpRet |       -1.84e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             255 |
# |     AverageQ1Vals |          -0.148 |
# |         StdQ1Vals |          0.0175 |
# |         MaxQ1Vals |          -0.118 |
# |         MinQ1Vals |          -0.178 |
# |     AverageQ2Vals |          -0.554 |
# |         StdQ2Vals |         0.00219 |
# |         MaxQ2Vals |          -0.549 |
# |         MinQ2Vals |          -0.558 |
# |      AverageLogPi |          -0.139 |
# |          StdLogPi |           0.903 |
# |          MaxLogPi |           0.788 |
# |          MinLogPi |           -6.32 |
# |            LossPi |           0.554 |
# |             LossQ |           0.183 |
# |              Time |            1.25 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.495 |
# |           asset_1 |           0.505 |
# |             Epoch |               5 |
# |      AverageEpRet |        -0.00126 |
# |          StdEpRet |        0.000837 |
# |          MaxEpRet |       -0.000427 |
# |          MinEpRet |         -0.0021 |
# |  AverageTestEpRet |        -0.00125 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -0.00125 |
# |      MinTestEpRet |        -0.00125 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             319 |
# |     AverageQ1Vals |          -0.211 |
# |         StdQ1Vals |           0.021 |
# |         MaxQ1Vals |          -0.179 |
# |         MinQ1Vals |          -0.266 |
# |     AverageQ2Vals |          -0.548 |
# |         StdQ2Vals |        0.000716 |
# |         MaxQ2Vals |          -0.546 |
# |         MinQ2Vals |          -0.549 |
# |      AverageLogPi |          -0.149 |
# |          StdLogPi |           0.918 |
# |          MaxLogPi |           0.788 |
# |          MinLogPi |           -7.68 |
# |            LossPi |           0.548 |
# |             LossQ |           0.131 |
# |              Time |            1.77 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.505 |
# |           asset_1 |           0.495 |
# |             Epoch |               6 |
# |      AverageEpRet |       -0.000944 |
# |          StdEpRet |        0.000574 |
# |          MaxEpRet |        -0.00037 |
# |          MinEpRet |        -0.00152 |
# |  AverageTestEpRet |       -0.000299 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000299 |
# |      MinTestEpRet |       -0.000299 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             383 |
# |     AverageQ1Vals |          -0.317 |
# |         StdQ1Vals |          0.0429 |
# |         MaxQ1Vals |          -0.236 |
# |         MinQ1Vals |          -0.467 |
# |     AverageQ2Vals |           -0.54 |
# |         StdQ2Vals |         0.00345 |
# |         MaxQ2Vals |          -0.535 |
# |         MinQ2Vals |          -0.546 |
# |      AverageLogPi |          -0.151 |
# |          StdLogPi |           0.914 |
# |          MaxLogPi |           0.787 |
# |          MinLogPi |           -6.99 |
# |            LossPi |           0.539 |
# |             LossQ |          0.0697 |
# |              Time |            2.29 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.544 |
# |           asset_1 |           0.456 |
# |             Epoch |               7 |
# |      AverageEpRet |        -0.00127 |
# |          StdEpRet |         0.00108 |
# |          MaxEpRet |       -0.000199 |
# |          MinEpRet |        -0.00235 |
# |  AverageTestEpRet |       -0.000211 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000211 |
# |      MinTestEpRet |       -0.000211 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             447 |
# |     AverageQ1Vals |          -0.441 |
# |         StdQ1Vals |          0.0498 |
# |         MaxQ1Vals |          -0.313 |
# |         MinQ1Vals |          -0.625 |
# |     AverageQ2Vals |          -0.535 |
# |         StdQ2Vals |         0.00234 |
# |         MaxQ2Vals |          -0.529 |
# |         MinQ2Vals |          -0.538 |
# |      AverageLogPi |          -0.172 |
# |          StdLogPi |           0.928 |
# |          MaxLogPi |           0.789 |
# |          MinLogPi |           -6.93 |
# |            LossPi |           0.536 |
# |             LossQ |          0.0284 |
# |              Time |            2.81 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.63 |
# |           asset_1 |            0.37 |
# |             Epoch |               8 |
# |      AverageEpRet |       -0.000188 |
# |          StdEpRet |         2.1e-05 |
# |          MaxEpRet |       -0.000167 |
# |          MinEpRet |       -0.000209 |
# |  AverageTestEpRet |       -0.000512 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000512 |
# |      MinTestEpRet |       -0.000512 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             511 |
# |     AverageQ1Vals |          -0.503 |
# |         StdQ1Vals |          0.0522 |
# |         MaxQ1Vals |          -0.333 |
# |         MinQ1Vals |          -0.667 |
# |     AverageQ2Vals |          -0.527 |
# |         StdQ2Vals |         0.00182 |
# |         MaxQ2Vals |          -0.521 |
# |         MinQ2Vals |          -0.529 |
# |      AverageLogPi |          -0.149 |
# |          StdLogPi |           0.904 |
# |          MaxLogPi |           0.812 |
# |          MinLogPi |           -8.39 |
# |            LossPi |           0.539 |
# |             LossQ |          0.0213 |
# |              Time |            3.47 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.686 |
# |           asset_1 |           0.314 |
# |             Epoch |               9 |
# |      AverageEpRet |       -0.000492 |
# |          StdEpRet |        9.41e-05 |
# |          MaxEpRet |       -0.000397 |
# |          MinEpRet |       -0.000586 |
# |  AverageTestEpRet |       -0.000579 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000579 |
# |      MinTestEpRet |       -0.000579 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             575 |
# |     AverageQ1Vals |          -0.509 |
# |         StdQ1Vals |          0.0527 |
# |         MaxQ1Vals |           -0.35 |
# |         MinQ1Vals |          -0.664 |
# |     AverageQ2Vals |          -0.518 |
# |         StdQ2Vals |         0.00253 |
# |         MaxQ2Vals |          -0.515 |
# |         MinQ2Vals |          -0.523 |
# |      AverageLogPi |          -0.132 |
# |          StdLogPi |           0.943 |
# |          MaxLogPi |            0.84 |
# |          MinLogPi |           -7.68 |
# |            LossPi |           0.535 |
# |             LossQ |          0.0202 |
# |              Time |            3.99 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.721 |
# |           asset_1 |           0.279 |
# |             Epoch |              10 |
# |      AverageEpRet |       -0.000609 |
# |          StdEpRet |        0.000213 |
# |          MaxEpRet |       -0.000397 |
# |          MinEpRet |       -0.000822 |
# |  AverageTestEpRet |       -9.88e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -9.88e-05 |
# |      MinTestEpRet |       -9.88e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             639 |
# |     AverageQ1Vals |          -0.506 |
# |         StdQ1Vals |          0.0501 |
# |         MaxQ1Vals |          -0.359 |
# |         MinQ1Vals |          -0.654 |
# |     AverageQ2Vals |          -0.516 |
# |         StdQ2Vals |           0.003 |
# |         MaxQ2Vals |           -0.51 |
# |         MinQ2Vals |           -0.52 |
# |      AverageLogPi |         -0.0687 |
# |          StdLogPi |           0.886 |
# |          MaxLogPi |           0.865 |
# |          MinLogPi |           -6.53 |
# |            LossPi |            0.53 |
# |             LossQ |          0.0177 |
# |              Time |             4.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.749 |
# |           asset_1 |           0.251 |
# |             Epoch |              11 |
# |      AverageEpRet |       -0.000286 |
# |          StdEpRet |        0.000127 |
# |          MaxEpRet |       -0.000159 |
# |          MinEpRet |       -0.000413 |
# |  AverageTestEpRet |       -3.05e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -3.05e-05 |
# |      MinTestEpRet |       -3.05e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             703 |
# |     AverageQ1Vals |          -0.501 |
# |         StdQ1Vals |          0.0456 |
# |         MaxQ1Vals |          -0.368 |
# |         MinQ1Vals |          -0.634 |
# |     AverageQ2Vals |          -0.507 |
# |         StdQ2Vals |         0.00293 |
# |         MaxQ2Vals |          -0.503 |
# |         MinQ2Vals |          -0.546 |
# |      AverageLogPi |         -0.0537 |
# |          StdLogPi |           0.918 |
# |          MaxLogPi |           0.889 |
# |          MinLogPi |           -6.37 |
# |            LossPi |           0.521 |
# |             LossQ |          0.0194 |
# |              Time |            4.99 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.771 |
# |           asset_1 |           0.229 |
# |             Epoch |              12 |
# |      AverageEpRet |       -0.000426 |
# |          StdEpRet |         9.7e-05 |
# |          MaxEpRet |       -0.000329 |
# |          MinEpRet |       -0.000523 |
# |  AverageTestEpRet |       -9.94e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -9.94e-05 |
# |      MinTestEpRet |       -9.94e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             767 |
# |     AverageQ1Vals |          -0.494 |
# |         StdQ1Vals |          0.0422 |
# |         MaxQ1Vals |          -0.373 |
# |         MinQ1Vals |          -0.623 |
# |     AverageQ2Vals |          -0.501 |
# |         StdQ2Vals |         0.00646 |
# |         MaxQ2Vals |          -0.496 |
# |         MinQ2Vals |           -0.55 |
# |      AverageLogPi |         -0.0476 |
# |          StdLogPi |           0.939 |
# |          MaxLogPi |           0.908 |
# |          MinLogPi |           -9.17 |
# |            LossPi |           0.511 |
# |             LossQ |          0.0175 |
# |              Time |            5.52 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.79 |
# |           asset_1 |            0.21 |
# |             Epoch |              13 |
# |      AverageEpRet |       -0.000182 |
# |          StdEpRet |        1.96e-05 |
# |          MaxEpRet |       -0.000163 |
# |          MinEpRet |       -0.000202 |
# |  AverageTestEpRet |       -0.000128 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000128 |
# |      MinTestEpRet |       -0.000128 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             831 |
# |     AverageQ1Vals |          -0.488 |
# |         StdQ1Vals |          0.0383 |
# |         MaxQ1Vals |          -0.379 |
# |         MinQ1Vals |          -0.606 |
# |     AverageQ2Vals |          -0.493 |
# |         StdQ2Vals |         0.00567 |
# |         MaxQ2Vals |          -0.489 |
# |         MinQ2Vals |          -0.532 |
# |      AverageLogPi |         -0.0346 |
# |          StdLogPi |            0.95 |
# |          MaxLogPi |           0.924 |
# |          MinLogPi |           -9.07 |
# |            LossPi |           0.503 |
# |             LossQ |          0.0175 |
# |              Time |            6.06 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.806 |
# |           asset_1 |           0.194 |
# |             Epoch |              14 |
# |      AverageEpRet |       -0.000456 |
# |          StdEpRet |        0.000251 |
# |          MaxEpRet |       -0.000205 |
# |          MinEpRet |       -0.000707 |
# |  AverageTestEpRet |       -3.48e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -3.48e-05 |
# |      MinTestEpRet |       -3.48e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             895 |
# |     AverageQ1Vals |          -0.483 |
# |         StdQ1Vals |          0.0349 |
# |         MaxQ1Vals |          -0.384 |
# |         MinQ1Vals |          -0.591 |
# |     AverageQ2Vals |          -0.487 |
# |         StdQ2Vals |         0.00582 |
# |         MaxQ2Vals |          -0.481 |
# |         MinQ2Vals |          -0.528 |
# |      AverageLogPi |         -0.0117 |
# |          StdLogPi |           0.944 |
# |          MaxLogPi |           0.939 |
# |          MinLogPi |           -7.75 |
# |            LossPi |           0.496 |
# |             LossQ |          0.0169 |
# |              Time |            6.57 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.82 |
# |           asset_1 |            0.18 |
# |             Epoch |              15 |
# |      AverageEpRet |       -0.000236 |
# |          StdEpRet |        0.000154 |
# |          MaxEpRet |       -8.23e-05 |
# |          MinEpRet |       -0.000391 |
# |  AverageTestEpRet |       -0.000384 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000384 |
# |      MinTestEpRet |       -0.000384 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             959 |
# |     AverageQ1Vals |          -0.477 |
# |         StdQ1Vals |           0.032 |
# |         MaxQ1Vals |          -0.384 |
# |         MinQ1Vals |          -0.573 |
# |     AverageQ2Vals |          -0.482 |
# |         StdQ2Vals |         0.00538 |
# |         MaxQ2Vals |          -0.478 |
# |         MinQ2Vals |          -0.516 |
# |      AverageLogPi |        -0.00397 |
# |          StdLogPi |           0.919 |
# |          MaxLogPi |           0.955 |
# |          MinLogPi |           -5.58 |
# |            LossPi |            0.49 |
# |             LossQ |          0.0164 |
# |              Time |            7.08 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.831 |
# |           asset_1 |           0.169 |
# |             Epoch |              16 |
# |      AverageEpRet |       -0.000365 |
# |          StdEpRet |        1.16e-05 |
# |          MaxEpRet |       -0.000354 |
# |          MinEpRet |       -0.000377 |
# |  AverageTestEpRet |       -4.93e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -4.93e-05 |
# |      MinTestEpRet |       -4.93e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.02e+03 |
# |     AverageQ1Vals |          -0.475 |
# |         StdQ1Vals |          0.0293 |
# |         MaxQ1Vals |          -0.384 |
# |         MinQ1Vals |          -0.568 |
# |     AverageQ2Vals |          -0.477 |
# |         StdQ2Vals |         0.00548 |
# |         MaxQ2Vals |          -0.472 |
# |         MinQ2Vals |          -0.513 |
# |      AverageLogPi |         0.00504 |
# |          StdLogPi |           0.936 |
# |          MaxLogPi |           0.966 |
# |          MinLogPi |           -7.62 |
# |            LossPi |           0.485 |
# |             LossQ |          0.0156 |
# |              Time |            7.59 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.839 |
# |           asset_1 |           0.161 |
# |             Epoch |              17 |
# |      AverageEpRet |       -0.000351 |
# |          StdEpRet |         0.00021 |
# |          MaxEpRet |       -0.000141 |
# |          MinEpRet |       -0.000561 |
# |  AverageTestEpRet |       -0.000518 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000518 |
# |      MinTestEpRet |       -0.000518 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.09e+03 |
# |     AverageQ1Vals |          -0.469 |
# |         StdQ1Vals |          0.0257 |
# |         MaxQ1Vals |          -0.386 |
# |         MinQ1Vals |          -0.552 |
# |     AverageQ2Vals |          -0.472 |
# |         StdQ2Vals |         0.00495 |
# |         MaxQ2Vals |          -0.468 |
# |         MinQ2Vals |          -0.513 |
# |      AverageLogPi |         0.00683 |
# |          StdLogPi |           0.969 |
# |          MaxLogPi |           0.975 |
# |          MinLogPi |            -7.5 |
# |            LossPi |           0.479 |
# |             LossQ |          0.0151 |
# |              Time |            8.12 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.845 |
# |           asset_1 |           0.155 |
# |             Epoch |              18 |
# |      AverageEpRet |       -0.000163 |
# |          StdEpRet |        2.33e-05 |
# |          MaxEpRet |        -0.00014 |
# |          MinEpRet |       -0.000187 |
# |  AverageTestEpRet |       -0.000101 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000101 |
# |      MinTestEpRet |       -0.000101 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.15e+03 |
# |     AverageQ1Vals |          -0.466 |
# |         StdQ1Vals |          0.0233 |
# |         MaxQ1Vals |           -0.39 |
# |         MinQ1Vals |          -0.539 |
# |     AverageQ2Vals |           -0.47 |
# |         StdQ2Vals |         0.00359 |
# |         MaxQ2Vals |          -0.467 |
# |         MinQ2Vals |          -0.501 |
# |      AverageLogPi |          0.0183 |
# |          StdLogPi |           0.948 |
# |          MaxLogPi |           0.983 |
# |          MinLogPi |           -7.26 |
# |            LossPi |           0.476 |
# |             LossQ |          0.0141 |
# |              Time |            8.63 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.85 |
# |           asset_1 |            0.15 |
# |             Epoch |              19 |
# |      AverageEpRet |       -0.000392 |
# |          StdEpRet |        0.000366 |
# |          MaxEpRet |       -2.65e-05 |
# |          MinEpRet |       -0.000758 |
# |  AverageTestEpRet |       -0.000296 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000296 |
# |      MinTestEpRet |       -0.000296 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.22e+03 |
# |     AverageQ1Vals |          -0.463 |
# |         StdQ1Vals |          0.0215 |
# |         MaxQ1Vals |          -0.395 |
# |         MinQ1Vals |           -0.53 |
# |     AverageQ2Vals |          -0.464 |
# |         StdQ2Vals |          0.0044 |
# |         MaxQ2Vals |           -0.46 |
# |         MinQ2Vals |          -0.499 |
# |      AverageLogPi |          0.0354 |
# |          StdLogPi |           0.923 |
# |          MaxLogPi |            0.99 |
# |          MinLogPi |           -5.72 |
# |            LossPi |           0.471 |
# |             LossQ |          0.0145 |
# |              Time |            9.12 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.853 |
# |           asset_1 |           0.147 |
# |             Epoch |              20 |
# |      AverageEpRet |       -0.000415 |
# |          StdEpRet |           8e-05 |
# |          MaxEpRet |       -0.000335 |
# |          MinEpRet |       -0.000495 |
# |  AverageTestEpRet |       -0.000357 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000357 |
# |      MinTestEpRet |       -0.000357 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.28e+03 |
# |     AverageQ1Vals |          -0.458 |
# |         StdQ1Vals |          0.0193 |
# |         MaxQ1Vals |          -0.399 |
# |         MinQ1Vals |          -0.519 |
# |     AverageQ2Vals |          -0.459 |
# |         StdQ2Vals |         0.00481 |
# |         MaxQ2Vals |          -0.454 |
# |         MinQ2Vals |          -0.494 |
# |      AverageLogPi |           0.021 |
# |          StdLogPi |           0.965 |
# |          MaxLogPi |           0.993 |
# |          MinLogPi |           -7.13 |
# |            LossPi |           0.465 |
# |             LossQ |           0.015 |
# |              Time |            9.66 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.857 |
# |           asset_1 |           0.143 |
# |             Epoch |              21 |
# |      AverageEpRet |       -0.000679 |
# |          StdEpRet |        0.000311 |
# |          MaxEpRet |       -0.000369 |
# |          MinEpRet |        -0.00099 |
# |  AverageTestEpRet |       -0.000119 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000119 |
# |      MinTestEpRet |       -0.000119 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.34e+03 |
# |     AverageQ1Vals |          -0.453 |
# |         StdQ1Vals |           0.017 |
# |         MaxQ1Vals |          -0.401 |
# |         MinQ1Vals |          -0.507 |
# |     AverageQ2Vals |          -0.454 |
# |         StdQ2Vals |         0.00445 |
# |         MaxQ2Vals |          -0.451 |
# |         MinQ2Vals |          -0.493 |
# |      AverageLogPi |          0.0197 |
# |          StdLogPi |           0.955 |
# |          MaxLogPi |           0.997 |
# |          MinLogPi |           -6.11 |
# |            LossPi |           0.459 |
# |             LossQ |          0.0145 |
# |              Time |            10.3 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.859 |
# |           asset_1 |           0.141 |
# |             Epoch |              22 |
# |      AverageEpRet |       -0.000545 |
# |          StdEpRet |        2.62e-05 |
# |          MaxEpRet |       -0.000519 |
# |          MinEpRet |       -0.000571 |
# |  AverageTestEpRet |       -2.89e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -2.89e-05 |
# |      MinTestEpRet |       -2.89e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.41e+03 |
# |     AverageQ1Vals |           -0.45 |
# |         StdQ1Vals |           0.015 |
# |         MaxQ1Vals |            -0.4 |
# |         MinQ1Vals |          -0.498 |
# |     AverageQ2Vals |          -0.451 |
# |         StdQ2Vals |         0.00435 |
# |         MaxQ2Vals |          -0.446 |
# |         MinQ2Vals |          -0.483 |
# |      AverageLogPi |          0.0406 |
# |          StdLogPi |           0.934 |
# |          MaxLogPi |           0.999 |
# |          MinLogPi |           -6.57 |
# |            LossPi |           0.455 |
# |             LossQ |          0.0134 |
# |              Time |            10.9 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.86 |
# |           asset_1 |            0.14 |
# |             Epoch |              23 |
# |      AverageEpRet |       -0.000204 |
# |          StdEpRet |        2.61e-06 |
# |          MaxEpRet |       -0.000202 |
# |          MinEpRet |       -0.000207 |
# |  AverageTestEpRet |        -2.6e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -2.6e-05 |
# |      MinTestEpRet |        -2.6e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.47e+03 |
# |     AverageQ1Vals |          -0.447 |
# |         StdQ1Vals |          0.0131 |
# |         MaxQ1Vals |          -0.404 |
# |         MinQ1Vals |          -0.489 |
# |     AverageQ2Vals |          -0.447 |
# |         StdQ2Vals |         0.00458 |
# |         MaxQ2Vals |          -0.442 |
# |         MinQ2Vals |           -0.48 |
# |      AverageLogPi |           0.042 |
# |          StdLogPi |            0.95 |
# |          MaxLogPi |               1 |
# |          MinLogPi |           -7.89 |
# |            LossPi |           0.451 |
# |             LossQ |          0.0121 |
# |              Time |            11.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.861 |
# |           asset_1 |           0.139 |
# |             Epoch |              24 |
# |      AverageEpRet |       -0.000805 |
# |          StdEpRet |        8.95e-05 |
# |          MaxEpRet |       -0.000716 |
# |          MinEpRet |       -0.000895 |
# |  AverageTestEpRet |       -0.000291 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000291 |
# |      MinTestEpRet |       -0.000291 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.54e+03 |
# |     AverageQ1Vals |          -0.442 |
# |         StdQ1Vals |          0.0114 |
# |         MaxQ1Vals |          -0.405 |
# |         MinQ1Vals |          -0.478 |
# |     AverageQ2Vals |          -0.442 |
# |         StdQ2Vals |         0.00428 |
# |         MaxQ2Vals |          -0.438 |
# |         MinQ2Vals |          -0.479 |
# |      AverageLogPi |          0.0436 |
# |          StdLogPi |            0.96 |
# |          MaxLogPi |               1 |
# |          MinLogPi |            -6.8 |
# |            LossPi |           0.446 |
# |             LossQ |          0.0127 |
# |              Time |              12 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.862 |
# |           asset_1 |           0.138 |
# |             Epoch |              25 |
# |      AverageEpRet |        -0.00062 |
# |          StdEpRet |        0.000151 |
# |          MaxEpRet |       -0.000468 |
# |          MinEpRet |       -0.000771 |
# |  AverageTestEpRet |       -5.14e-07 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -5.14e-07 |
# |      MinTestEpRet |       -5.14e-07 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         1.6e+03 |
# |     AverageQ1Vals |          -0.437 |
# |         StdQ1Vals |         0.00982 |
# |         MaxQ1Vals |          -0.406 |
# |         MinQ1Vals |          -0.469 |
# |     AverageQ2Vals |          -0.436 |
# |         StdQ2Vals |         0.00407 |
# |         MaxQ2Vals |          -0.433 |
# |         MinQ2Vals |          -0.473 |
# |      AverageLogPi |          0.0265 |
# |          StdLogPi |            0.96 |
# |          MaxLogPi |               1 |
# |          MinLogPi |            -7.2 |
# |            LossPi |            0.44 |
# |             LossQ |          0.0132 |
# |              Time |            12.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.863 |
# |           asset_1 |           0.137 |
# |             Epoch |              26 |
# |      AverageEpRet |       -0.000472 |
# |          StdEpRet |        0.000283 |
# |          MaxEpRet |       -0.000189 |
# |          MinEpRet |       -0.000755 |
# |  AverageTestEpRet |       -8.33e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -8.33e-05 |
# |      MinTestEpRet |       -8.33e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.66e+03 |
# |     AverageQ1Vals |          -0.433 |
# |         StdQ1Vals |         0.00833 |
# |         MaxQ1Vals |          -0.406 |
# |         MinQ1Vals |          -0.459 |
# |     AverageQ2Vals |          -0.434 |
# |         StdQ2Vals |         0.00389 |
# |         MaxQ2Vals |          -0.431 |
# |         MinQ2Vals |          -0.468 |
# |      AverageLogPi |           0.041 |
# |          StdLogPi |           0.937 |
# |          MaxLogPi |            1.01 |
# |          MinLogPi |           -6.24 |
# |            LossPi |           0.436 |
# |             LossQ |          0.0107 |
# |              Time |              13 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.864 |
# |           asset_1 |           0.136 |
# |             Epoch |              27 |
# |      AverageEpRet |        -0.00311 |
# |          StdEpRet |         0.00167 |
# |          MaxEpRet |        -0.00144 |
# |          MinEpRet |        -0.00477 |
# |  AverageTestEpRet |       -0.000341 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000341 |
# |      MinTestEpRet |       -0.000341 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.73e+03 |
# |     AverageQ1Vals |          -0.429 |
# |         StdQ1Vals |          0.0073 |
# |         MaxQ1Vals |          -0.406 |
# |         MinQ1Vals |          -0.454 |
# |     AverageQ2Vals |          -0.428 |
# |         StdQ2Vals |         0.00394 |
# |         MaxQ2Vals |          -0.424 |
# |         MinQ2Vals |          -0.462 |
# |      AverageLogPi |          0.0383 |
# |          StdLogPi |           0.942 |
# |          MaxLogPi |            1.01 |
# |          MinLogPi |           -5.59 |
# |            LossPi |           0.431 |
# |             LossQ |          0.0117 |
# |              Time |            13.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.866 |
# |           asset_1 |           0.134 |
# |             Epoch |              28 |
# |      AverageEpRet |       -0.000605 |
# |          StdEpRet |        0.000302 |
# |          MaxEpRet |       -0.000303 |
# |          MinEpRet |       -0.000907 |
# |  AverageTestEpRet |       -0.000213 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000213 |
# |      MinTestEpRet |       -0.000213 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.79e+03 |
# |     AverageQ1Vals |          -0.423 |
# |         StdQ1Vals |           0.006 |
# |         MaxQ1Vals |          -0.405 |
# |         MinQ1Vals |          -0.443 |
# |     AverageQ2Vals |          -0.423 |
# |         StdQ2Vals |         0.00393 |
# |         MaxQ2Vals |          -0.419 |
# |         MinQ2Vals |          -0.454 |
# |      AverageLogPi |          0.0569 |
# |          StdLogPi |           0.942 |
# |          MaxLogPi |            1.01 |
# |          MinLogPi |           -6.69 |
# |            LossPi |           0.425 |
# |             LossQ |          0.0121 |
# |              Time |              14 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.871 |
# |           asset_1 |           0.129 |
# |             Epoch |              29 |
# |      AverageEpRet |       -0.000271 |
# |          StdEpRet |        2.38e-05 |
# |          MaxEpRet |       -0.000247 |
# |          MinEpRet |       -0.000295 |
# |  AverageTestEpRet |       -0.000133 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000133 |
# |      MinTestEpRet |       -0.000133 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.86e+03 |
# |     AverageQ1Vals |          -0.417 |
# |         StdQ1Vals |         0.00518 |
# |         MaxQ1Vals |            -0.4 |
# |         MinQ1Vals |          -0.435 |
# |     AverageQ2Vals |          -0.415 |
# |         StdQ2Vals |         0.00453 |
# |         MaxQ2Vals |          -0.411 |
# |         MinQ2Vals |          -0.446 |
# |      AverageLogPi |          0.0545 |
# |          StdLogPi |           0.957 |
# |          MaxLogPi |            1.01 |
# |          MinLogPi |            -6.4 |
# |            LossPi |           0.418 |
# |             LossQ |          0.0129 |
# |              Time |            14.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.875 |
# |           asset_1 |           0.125 |
# |             Epoch |              30 |
# |      AverageEpRet |       -0.000111 |
# |          StdEpRet |        8.38e-05 |
# |          MaxEpRet |       -2.72e-05 |
# |          MinEpRet |       -0.000195 |
# |  AverageTestEpRet |       -8.39e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -8.39e-05 |
# |      MinTestEpRet |       -8.39e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.92e+03 |
# |     AverageQ1Vals |          -0.414 |
# |         StdQ1Vals |         0.00447 |
# |         MaxQ1Vals |          -0.398 |
# |         MinQ1Vals |          -0.427 |
# |     AverageQ2Vals |          -0.413 |
# |         StdQ2Vals |          0.0043 |
# |         MaxQ2Vals |          -0.408 |
# |         MinQ2Vals |          -0.447 |
# |      AverageLogPi |          0.0739 |
# |          StdLogPi |            0.92 |
# |          MaxLogPi |            1.02 |
# |          MinLogPi |           -6.41 |
# |            LossPi |           0.415 |
# |             LossQ |          0.0109 |
# |              Time |            15.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.879 |
# |           asset_1 |           0.121 |
# |             Epoch |              31 |
# |      AverageEpRet |        -0.00054 |
# |          StdEpRet |        0.000314 |
# |          MaxEpRet |       -0.000227 |
# |          MinEpRet |       -0.000854 |
# |  AverageTestEpRet |        -1.7e-06 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -1.7e-06 |
# |      MinTestEpRet |        -1.7e-06 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.98e+03 |
# |     AverageQ1Vals |          -0.409 |
# |         StdQ1Vals |         0.00386 |
# |         MaxQ1Vals |          -0.397 |
# |         MinQ1Vals |          -0.421 |
# |     AverageQ2Vals |          -0.408 |
# |         StdQ2Vals |         0.00398 |
# |         MaxQ2Vals |          -0.402 |
# |         MinQ2Vals |          -0.433 |
# |      AverageLogPi |          0.0815 |
# |          StdLogPi |           0.924 |
# |          MaxLogPi |            1.03 |
# |          MinLogPi |           -6.34 |
# |            LossPi |            0.41 |
# |             LossQ |           0.011 |
# |              Time |            15.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.884 |
# |           asset_1 |           0.116 |
# |             Epoch |              32 |
# |      AverageEpRet |       -0.000419 |
# |          StdEpRet |        0.000391 |
# |          MaxEpRet |       -2.77e-05 |
# |          MinEpRet |        -0.00081 |
# |  AverageTestEpRet |       -0.000169 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000169 |
# |      MinTestEpRet |       -0.000169 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.05e+03 |
# |     AverageQ1Vals |          -0.403 |
# |         StdQ1Vals |         0.00285 |
# |         MaxQ1Vals |          -0.394 |
# |         MinQ1Vals |          -0.413 |
# |     AverageQ2Vals |          -0.403 |
# |         StdQ2Vals |         0.00245 |
# |         MaxQ2Vals |          -0.401 |
# |         MinQ2Vals |          -0.426 |
# |      AverageLogPi |          0.0507 |
# |          StdLogPi |           0.963 |
# |          MaxLogPi |            1.03 |
# |          MinLogPi |           -8.04 |
# |            LossPi |           0.404 |
# |             LossQ |          0.0108 |
# |              Time |            16.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.888 |
# |           asset_1 |           0.112 |
# |             Epoch |              33 |
# |      AverageEpRet |       -0.000734 |
# |          StdEpRet |        0.000404 |
# |          MaxEpRet |        -0.00033 |
# |          MinEpRet |        -0.00114 |
# |  AverageTestEpRet |       -0.000136 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000136 |
# |      MinTestEpRet |       -0.000136 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.11e+03 |
# |     AverageQ1Vals |          -0.398 |
# |         StdQ1Vals |         0.00235 |
# |         MaxQ1Vals |          -0.391 |
# |         MinQ1Vals |          -0.406 |
# |     AverageQ2Vals |          -0.396 |
# |         StdQ2Vals |         0.00219 |
# |         MaxQ2Vals |          -0.394 |
# |         MinQ2Vals |          -0.416 |
# |      AverageLogPi |          0.0696 |
# |          StdLogPi |           0.969 |
# |          MaxLogPi |            1.04 |
# |          MinLogPi |           -8.97 |
# |            LossPi |           0.398 |
# |             LossQ |          0.0115 |
# |              Time |            16.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.891 |
# |           asset_1 |           0.109 |
# |             Epoch |              34 |
# |      AverageEpRet |       -4.49e-05 |
# |          StdEpRet |        3.82e-05 |
# |          MaxEpRet |       -6.74e-06 |
# |          MinEpRet |       -8.31e-05 |
# |  AverageTestEpRet |       -8.95e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -8.95e-05 |
# |      MinTestEpRet |       -8.95e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.18e+03 |
# |     AverageQ1Vals |          -0.393 |
# |         StdQ1Vals |         0.00181 |
# |         MaxQ1Vals |          -0.388 |
# |         MinQ1Vals |          -0.398 |
# |     AverageQ2Vals |          -0.392 |
# |         StdQ2Vals |         0.00262 |
# |         MaxQ2Vals |           -0.39 |
# |         MinQ2Vals |          -0.415 |
# |      AverageLogPi |          0.0681 |
# |          StdLogPi |           0.967 |
# |          MaxLogPi |            1.04 |
# |          MinLogPi |           -8.72 |
# |            LossPi |           0.393 |
# |             LossQ |         0.00993 |
# |              Time |            17.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.895 |
# |           asset_1 |           0.105 |
# |             Epoch |              35 |
# |      AverageEpRet |       -0.000234 |
# |          StdEpRet |        2.81e-05 |
# |          MaxEpRet |       -0.000206 |
# |          MinEpRet |       -0.000262 |
# |  AverageTestEpRet |       -0.000196 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000196 |
# |      MinTestEpRet |       -0.000196 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.24e+03 |
# |     AverageQ1Vals |          -0.388 |
# |         StdQ1Vals |         0.00217 |
# |         MaxQ1Vals |          -0.383 |
# |         MinQ1Vals |          -0.394 |
# |     AverageQ2Vals |          -0.387 |
# |         StdQ2Vals |         0.00323 |
# |         MaxQ2Vals |          -0.385 |
# |         MinQ2Vals |          -0.414 |
# |      AverageLogPi |          0.0781 |
# |          StdLogPi |           0.967 |
# |          MaxLogPi |            1.04 |
# |          MinLogPi |           -9.34 |
# |            LossPi |           0.388 |
# |             LossQ |         0.00997 |
# |              Time |            17.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.898 |
# |           asset_1 |           0.102 |
# |             Epoch |              36 |
# |      AverageEpRet |       -0.000341 |
# |          StdEpRet |        0.000297 |
# |          MaxEpRet |       -4.46e-05 |
# |          MinEpRet |       -0.000638 |
# |  AverageTestEpRet |        -7.8e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -7.8e-05 |
# |      MinTestEpRet |        -7.8e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.3e+03 |
# |     AverageQ1Vals |          -0.384 |
# |         StdQ1Vals |         0.00248 |
# |         MaxQ1Vals |          -0.376 |
# |         MinQ1Vals |          -0.389 |
# |     AverageQ2Vals |          -0.383 |
# |         StdQ2Vals |         0.00401 |
# |         MaxQ2Vals |          -0.378 |
# |         MinQ2Vals |           -0.41 |
# |      AverageLogPi |          0.0728 |
# |          StdLogPi |           0.966 |
# |          MaxLogPi |            1.05 |
# |          MinLogPi |           -8.28 |
# |            LossPi |           0.384 |
# |             LossQ |          0.0099 |
# |              Time |            18.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.903 |
# |           asset_1 |          0.0973 |
# |             Epoch |              37 |
# |      AverageEpRet |       -0.000884 |
# |          StdEpRet |        0.000377 |
# |          MaxEpRet |       -0.000507 |
# |          MinEpRet |        -0.00126 |
# |  AverageTestEpRet |       -2.81e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -2.81e-05 |
# |      MinTestEpRet |       -2.81e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.37e+03 |
# |     AverageQ1Vals |          -0.379 |
# |         StdQ1Vals |         0.00158 |
# |         MaxQ1Vals |          -0.373 |
# |         MinQ1Vals |          -0.384 |
# |     AverageQ2Vals |          -0.378 |
# |         StdQ2Vals |         0.00262 |
# |         MaxQ2Vals |          -0.376 |
# |         MinQ2Vals |          -0.404 |
# |      AverageLogPi |          0.0959 |
# |          StdLogPi |           0.952 |
# |          MaxLogPi |            1.06 |
# |          MinLogPi |           -8.54 |
# |            LossPi |           0.379 |
# |             LossQ |         0.00907 |
# |              Time |            18.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.908 |
# |           asset_1 |          0.0923 |
# |             Epoch |              38 |
# |      AverageEpRet |       -0.000754 |
# |          StdEpRet |         0.00017 |
# |          MaxEpRet |       -0.000584 |
# |          MinEpRet |       -0.000923 |
# |  AverageTestEpRet |       -0.000186 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000186 |
# |      MinTestEpRet |       -0.000186 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.43e+03 |
# |     AverageQ1Vals |          -0.375 |
# |         StdQ1Vals |         0.00236 |
# |         MaxQ1Vals |          -0.368 |
# |         MinQ1Vals |          -0.381 |
# |     AverageQ2Vals |          -0.373 |
# |         StdQ2Vals |         0.00258 |
# |         MaxQ2Vals |           -0.37 |
# |         MinQ2Vals |          -0.398 |
# |      AverageLogPi |          0.0855 |
# |          StdLogPi |           0.952 |
# |          MaxLogPi |            1.06 |
# |          MinLogPi |           -9.95 |
# |            LossPi |           0.374 |
# |             LossQ |         0.00941 |
# |              Time |            19.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.913 |
# |           asset_1 |          0.0865 |
# |             Epoch |              39 |
# |      AverageEpRet |       -0.000342 |
# |          StdEpRet |        0.000101 |
# |          MaxEpRet |       -0.000241 |
# |          MinEpRet |       -0.000442 |
# |  AverageTestEpRet |        -0.00011 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -0.00011 |
# |      MinTestEpRet |        -0.00011 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.5e+03 |
# |     AverageQ1Vals |          -0.371 |
# |         StdQ1Vals |         0.00209 |
# |         MaxQ1Vals |          -0.364 |
# |         MinQ1Vals |          -0.377 |
# |     AverageQ2Vals |           -0.37 |
# |         StdQ2Vals |         0.00278 |
# |         MaxQ2Vals |          -0.367 |
# |         MinQ2Vals |          -0.396 |
# |      AverageLogPi |           0.104 |
# |          StdLogPi |           0.948 |
# |          MaxLogPi |            1.07 |
# |          MinLogPi |           -6.89 |
# |            LossPi |            0.37 |
# |             LossQ |         0.00803 |
# |              Time |            19.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.919 |
# |           asset_1 |          0.0806 |
# |             Epoch |              40 |
# |      AverageEpRet |       -0.000457 |
# |          StdEpRet |        0.000387 |
# |          MaxEpRet |       -7.01e-05 |
# |          MinEpRet |       -0.000844 |
# |  AverageTestEpRet |       -0.000135 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000135 |
# |      MinTestEpRet |       -0.000135 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.56e+03 |
# |     AverageQ1Vals |          -0.366 |
# |         StdQ1Vals |         0.00257 |
# |         MaxQ1Vals |          -0.356 |
# ...
# |             Epoch |             388 |
# |      AverageEpRet |       -6.36e-05 |
# |          StdEpRet |        1.68e-05 |
# |          MaxEpRet |       -4.68e-05 |
# |          MinEpRet |       -8.05e-05 |
# |  AverageTestEpRet |       -5.48e-06 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -5.48e-06 |
# |      MinTestEpRet |       -5.48e-06 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.48e+04 |
# |     AverageQ1Vals |        -0.00449 |
# |         StdQ1Vals |        0.000171 |
# |         MaxQ1Vals |        -0.00411 |
# |         MinQ1Vals |        -0.00485 |
# |     AverageQ2Vals |        -0.00449 |
# |         StdQ2Vals |        0.000174 |
# |         MaxQ2Vals |        -0.00411 |
# |         MinQ2Vals |        -0.00504 |
# |      AverageLogPi |           0.227 |
# |          StdLogPi |           0.971 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -6.57 |
# |            LossPi |         0.00449 |
# |             LossQ |        1.41e-06 |
# |              Time |             199 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000137 |
# |             Epoch |             389 |
# |      AverageEpRet |       -0.000223 |
# |          StdEpRet |        9.62e-05 |
# |          MaxEpRet |       -0.000126 |
# |          MinEpRet |       -0.000319 |
# |  AverageTestEpRet |       -5.52e-06 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -5.52e-06 |
# |      MinTestEpRet |       -5.52e-06 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.49e+04 |
# |     AverageQ1Vals |        -0.00445 |
# |         StdQ1Vals |        0.000119 |
# |         MaxQ1Vals |         -0.0042 |
# |         MinQ1Vals |        -0.00486 |
# |     AverageQ2Vals |        -0.00445 |
# |         StdQ2Vals |        0.000118 |
# |         MaxQ2Vals |        -0.00421 |
# |         MinQ2Vals |         -0.0048 |
# |      AverageLogPi |           0.216 |
# |          StdLogPi |           0.959 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -6.98 |
# |            LossPi |         0.00445 |
# |             LossQ |        1.25e-06 |
# |              Time |             200 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000135 |
# |             Epoch |             390 |
# |      AverageEpRet |       -0.000139 |
# |          StdEpRet |        8.42e-05 |
# |          MaxEpRet |       -5.48e-05 |
# |          MinEpRet |       -0.000223 |
# |  AverageTestEpRet |       -0.000668 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000668 |
# |      MinTestEpRet |       -0.000668 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.5e+04 |
# |     AverageQ1Vals |         -0.0044 |
# |         StdQ1Vals |        0.000126 |
# |         MaxQ1Vals |        -0.00411 |
# |         MinQ1Vals |        -0.00466 |
# |     AverageQ2Vals |         -0.0044 |
# |         StdQ2Vals |         0.00013 |
# |         MaxQ2Vals |        -0.00411 |
# |         MinQ2Vals |        -0.00498 |
# |      AverageLogPi |           0.221 |
# |          StdLogPi |           0.956 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -7.84 |
# |            LossPi |          0.0044 |
# |             LossQ |        1.14e-06 |
# |              Time |             200 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000133 |
# |             Epoch |             391 |
# |      AverageEpRet |        -0.00021 |
# |          StdEpRet |        0.000135 |
# |          MaxEpRet |       -7.49e-05 |
# |          MinEpRet |       -0.000345 |
# |  AverageTestEpRet |       -0.000289 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000289 |
# |      MinTestEpRet |       -0.000289 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.5e+04 |
# |     AverageQ1Vals |        -0.00436 |
# |         StdQ1Vals |        0.000218 |
# |         MaxQ1Vals |        -0.00389 |
# |         MinQ1Vals |        -0.00483 |
# |     AverageQ2Vals |        -0.00436 |
# |         StdQ2Vals |        0.000217 |
# |         MaxQ2Vals |         -0.0039 |
# |         MinQ2Vals |        -0.00481 |
# |      AverageLogPi |           0.229 |
# |          StdLogPi |           0.966 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -6.89 |
# |            LossPi |         0.00436 |
# |             LossQ |        1.21e-06 |
# |              Time |             201 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000132 |
# |             Epoch |             392 |
# |      AverageEpRet |       -0.000667 |
# |          StdEpRet |        0.000435 |
# |          MaxEpRet |       -0.000232 |
# |          MinEpRet |         -0.0011 |
# |  AverageTestEpRet |       -0.000174 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000174 |
# |      MinTestEpRet |       -0.000174 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.51e+04 |
# |     AverageQ1Vals |        -0.00429 |
# |         StdQ1Vals |        0.000123 |
# |         MaxQ1Vals |        -0.00408 |
# |         MinQ1Vals |        -0.00474 |
# |     AverageQ2Vals |        -0.00429 |
# |         StdQ2Vals |        0.000126 |
# |         MaxQ2Vals |        -0.00408 |
# |         MinQ2Vals |        -0.00479 |
# |      AverageLogPi |           0.213 |
# |          StdLogPi |           0.959 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -6.25 |
# |            LossPi |         0.00429 |
# |             LossQ |        1.26e-06 |
# |              Time |             201 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000131 |
# |             Epoch |             393 |
# |      AverageEpRet |        -0.00102 |
# |          StdEpRet |        0.000371 |
# |          MaxEpRet |       -0.000648 |
# |          MinEpRet |        -0.00139 |
# |  AverageTestEpRet |       -0.000111 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000111 |
# |      MinTestEpRet |       -0.000111 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.52e+04 |
# |     AverageQ1Vals |        -0.00423 |
# |         StdQ1Vals |        7.89e-05 |
# |         MaxQ1Vals |        -0.00407 |
# |         MinQ1Vals |        -0.00453 |
# |     AverageQ2Vals |        -0.00423 |
# |         StdQ2Vals |        8.03e-05 |
# |         MaxQ2Vals |        -0.00407 |
# |         MinQ2Vals |        -0.00454 |
# |      AverageLogPi |           0.237 |
# |          StdLogPi |           0.963 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |            -6.6 |
# |            LossPi |         0.00423 |
# |             LossQ |        1.27e-06 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000129 |
# |             Epoch |             394 |
# |      AverageEpRet |       -0.000369 |
# |          StdEpRet |        0.000182 |
# |          MaxEpRet |       -0.000187 |
# |          MinEpRet |        -0.00055 |
# |  AverageTestEpRet |       -0.000135 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000135 |
# |      MinTestEpRet |       -0.000135 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.52e+04 |
# |     AverageQ1Vals |        -0.00416 |
# |         StdQ1Vals |         0.00019 |
# |         MaxQ1Vals |        -0.00377 |
# |         MinQ1Vals |        -0.00458 |
# |     AverageQ2Vals |        -0.00416 |
# |         StdQ2Vals |        0.000191 |
# |         MaxQ2Vals |        -0.00377 |
# |         MinQ2Vals |        -0.00475 |
# |      AverageLogPi |           0.217 |
# |          StdLogPi |           0.967 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -7.02 |
# |            LossPi |         0.00416 |
# |             LossQ |        1.33e-06 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000127 |
# |             Epoch |             395 |
# |      AverageEpRet |        -0.00105 |
# |          StdEpRet |        5.86e-05 |
# |          MaxEpRet |       -0.000993 |
# |          MinEpRet |        -0.00111 |
# |  AverageTestEpRet |       -0.000175 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000175 |
# |      MinTestEpRet |       -0.000175 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.53e+04 |
# |     AverageQ1Vals |        -0.00413 |
# |         StdQ1Vals |        0.000144 |
# |         MaxQ1Vals |        -0.00384 |
# |         MinQ1Vals |        -0.00452 |
# |     AverageQ2Vals |        -0.00413 |
# |         StdQ2Vals |        0.000145 |
# |         MaxQ2Vals |        -0.00384 |
# |         MinQ2Vals |        -0.00474 |
# |      AverageLogPi |           0.233 |
# |          StdLogPi |           0.939 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |            -7.1 |
# |            LossPi |         0.00413 |
# |             LossQ |        1.14e-06 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000126 |
# |             Epoch |             396 |
# |      AverageEpRet |       -0.000737 |
# |          StdEpRet |        0.000635 |
# |          MaxEpRet |       -0.000102 |
# |          MinEpRet |        -0.00137 |
# |  AverageTestEpRet |        -6.9e-06 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -6.9e-06 |
# |      MinTestEpRet |        -6.9e-06 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.53e+04 |
# |     AverageQ1Vals |        -0.00408 |
# |         StdQ1Vals |        0.000183 |
# |         MaxQ1Vals |        -0.00373 |
# |         MinQ1Vals |        -0.00454 |
# |     AverageQ2Vals |        -0.00408 |
# |         StdQ2Vals |        0.000183 |
# |         MaxQ2Vals |        -0.00373 |
# |         MinQ2Vals |        -0.00459 |
# |      AverageLogPi |           0.211 |
# |          StdLogPi |            0.98 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -7.43 |
# |            LossPi |         0.00407 |
# |             LossQ |        1.17e-06 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000125 |
# |             Epoch |             397 |
# |      AverageEpRet |       -0.000273 |
# |          StdEpRet |        0.000153 |
# |          MaxEpRet |        -0.00012 |
# |          MinEpRet |       -0.000425 |
# |  AverageTestEpRet |       -1.59e-08 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -1.59e-08 |
# |      MinTestEpRet |       -1.59e-08 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.54e+04 |
# |     AverageQ1Vals |        -0.00403 |
# |         StdQ1Vals |        0.000111 |
# |         MaxQ1Vals |        -0.00379 |
# |         MinQ1Vals |        -0.00428 |
# |     AverageQ2Vals |        -0.00403 |
# |         StdQ2Vals |        0.000111 |
# |         MaxQ2Vals |        -0.00379 |
# |         MinQ2Vals |         -0.0045 |
# |      AverageLogPi |           0.214 |
# |          StdLogPi |           0.991 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -7.09 |
# |            LossPi |         0.00403 |
# |             LossQ |        1.07e-06 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000124 |
# |             Epoch |             398 |
# |      AverageEpRet |       -0.000547 |
# |          StdEpRet |         0.00042 |
# |          MaxEpRet |       -0.000127 |
# |          MinEpRet |       -0.000966 |
# |  AverageTestEpRet |       -5.52e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -5.52e-05 |
# |      MinTestEpRet |       -5.52e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |        -0.00397 |
# |         StdQ1Vals |        0.000112 |
# |         MaxQ1Vals |        -0.00372 |
# |         MinQ1Vals |        -0.00429 |
# |     AverageQ2Vals |        -0.00397 |
# |         StdQ2Vals |        0.000112 |
# |         MaxQ2Vals |        -0.00372 |
# |         MinQ2Vals |        -0.00431 |
# |      AverageLogPi |           0.235 |
# |          StdLogPi |           0.965 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -8.49 |
# |            LossPi |         0.00397 |
# |             LossQ |        1.09e-06 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |        0.000122 |
# |             Epoch |             399 |
# |      AverageEpRet |       -0.000373 |
# |          StdEpRet |        0.000282 |
# |          MaxEpRet |       -9.14e-05 |
# |          MinEpRet |       -0.000655 |
# |  AverageTestEpRet |       -0.000559 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |       -0.000559 |
# |      MinTestEpRet |       -0.000559 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |        -0.00395 |
# |         StdQ1Vals |        0.000139 |
# |         MaxQ1Vals |        -0.00364 |
# |         MinQ1Vals |        -0.00443 |
# |     AverageQ2Vals |        -0.00395 |
# |         StdQ2Vals |        0.000141 |
# |         MaxQ2Vals |        -0.00364 |
# |         MinQ2Vals |        -0.00452 |
# |      AverageLogPi |           0.223 |
# |          StdLogPi |           0.961 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |            -7.1 |
# |            LossPi |         0.00396 |
# |             LossQ |        9.16e-07 |
# |              Time |             205 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |               1 |
# |           asset_1 |         0.00012 |
# |             Epoch |             400 |
# |      AverageEpRet |        -0.00037 |
# |          StdEpRet |        9.32e-05 |
# |          MaxEpRet |       -0.000277 |
# |          MinEpRet |       -0.000463 |
# |  AverageTestEpRet |        -3.9e-05 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -3.9e-05 |
# |      MinTestEpRet |        -3.9e-05 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.56e+04 |
# |     AverageQ1Vals |        -0.00389 |
# |         StdQ1Vals |        8.54e-05 |
# |         MaxQ1Vals |        -0.00374 |
# |         MinQ1Vals |        -0.00427 |
# |     AverageQ2Vals |        -0.00389 |
# |         StdQ2Vals |        8.54e-05 |
# |         MaxQ2Vals |        -0.00375 |
# |         MinQ2Vals |        -0.00427 |
# |      AverageLogPi |           0.223 |
# |          StdLogPi |           0.983 |
# |          MaxLogPi |             1.2 |
# |          MinLogPi |           -7.16 |
# |            LossPi |         0.00389 |
# |             LossQ |        9.76e-07 |
# |              Time |             205 |
# ---------------------------------------

# %%
out_reward_window=datetime.timedelta(days=1)
meta_parameters = {"in_bars_count": 30,
                   "out_reward_window":out_reward_window ,
                   "state_type":"in_window_out_window",
                   "asset_names":["asset_1","asset_2"],
                   "include_previous_weights":False}

objective_parameters = {"percent_commission": .001,
                        "reward_function":"cum_return"
                        }
features=pd.read_parquet("/home/jose/code/capstone/temp_persisted_data/only_features_simulation_gbm")
forward_returns_dates=pd.read_parquet("/home/jose/code/capstone/temp_persisted_data/forward_return_dates_simulation_gbm")
forward_returns= pd.read_parquet("/home/jose/code/capstone/temp_persisted_data/only_forward_returns_simulation_gbm")
new_environment= DeepTradingEnvironment(objective_parameters=objective_parameters,meta_parameters=meta_parameters,
                                        features=features,
                                        forward_returns=forward_returns,
                                        forward_returns_dates=forward_returns_dates)



env_fun =lambda : DeepTradingEnvironment(objective_parameters=objective_parameters,meta_parameters=meta_parameters,
                                        features=features,
                                        forward_returns=forward_returns,
                                        forward_returns_dates=forward_returns_dates)



#cum return
sac_capstone(env_fn=env_fun,actor_critic=MLPActorCriticCapstone,ac_kwargs={"hidden_sizes":(1,)},update_every=32,steps_per_epoch=64,epochs=400,
             start_steps=32,update_after=32*5,alpha=.001, lr=1e-3,save_freq=10000,num_test_episodes=1
            )
# Out:
# Logging data to /tmp/experiments/1607280398/progress.txt
# Saving config:
#
# {
#     "ac_kwargs":	{
#         "hidden_sizes":	[
#             1
#         ]
#     },
#     "actor_critic":	"MLPActorCritic",
#     "alpha":	0.001,
#     "batch_size":	100,
#     "env_fn":	"<function <lambda> at 0x7fc2f8110e60>",
#     "epochs":	400,
#     "gamma":	0.99,
#     "logger":	{
#         "<spinup.utils.logx.EpochLogger object at 0x7fc2fa772410>":	{
#             "epoch_dict":	{},
#             "exp_name":	null,
#             "first_row":	true,
#             "log_current_row":	{},
#             "log_headers":	[],
#             "output_dir":	"/tmp/experiments/1607280398",
#             "output_file":	{
#                 "<_io.TextIOWrapper name='/tmp/experiments/1607280398/progress.txt' mode='w' encoding='UTF-8'>":	{
#                     "mode":	"w"
#                 }
#             }
#         }
#     },
#     "logger_kwargs":	{},
#     "lr":	0.001,
#     "max_ep_len":	1000,
#     "num_test_episodes":	1,
#     "polyak":	0.995,
#     "replay_size":	1000000,
#     "save_freq":	10000,
#     "seed":	0,
#     "start_steps":	32,
#     "steps_per_epoch":	64,
#     "update_after":	160,
#     "update_every":	32
# }
#
# Number of parameters: 	 pi: 71, 	 q1: 67, 	 q2: 67
# /home/jose/venv/p37_deep_trading/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# |           asset_0 |           0.468 |
# |           asset_1 |           0.532 |
# |             Epoch |               3 |
# |      AverageEpRet |            0.14 |
# |          StdEpRet |          0.0388 |
# |          MaxEpRet |           0.208 |
# |          MinEpRet |          0.0829 |
# |  AverageTestEpRet |           0.217 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.217 |
# |      MinTestEpRet |           0.217 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             191 |
# |     AverageQ1Vals |          -0.101 |
# |         StdQ1Vals |         0.00945 |
# |         MaxQ1Vals |         -0.0834 |
# |         MinQ1Vals |          -0.117 |
# |     AverageQ2Vals |          -0.567 |
# |         StdQ2Vals |         0.00738 |
# |         MaxQ2Vals |          -0.557 |
# |         MinQ2Vals |          -0.589 |
# |      AverageLogPi |          -0.174 |
# |          StdLogPi |           0.943 |
# |          MaxLogPi |           0.789 |
# |          MinLogPi |           -8.65 |
# |            LossPi |           0.566 |
# |             LossQ |           0.224 |
# |              Time |           0.694 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.481 |
# |           asset_1 |           0.519 |
# |             Epoch |               4 |
# |      AverageEpRet |           0.177 |
# |          StdEpRet |          0.0913 |
# |          MaxEpRet |           0.268 |
# |          MinEpRet |          0.0856 |
# |  AverageTestEpRet |          0.0244 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0244 |
# |      MinTestEpRet |          0.0244 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             255 |
# |     AverageQ1Vals |          -0.148 |
# |         StdQ1Vals |          0.0175 |
# |         MaxQ1Vals |          -0.118 |
# |         MinQ1Vals |          -0.178 |
# |     AverageQ2Vals |           -0.55 |
# |         StdQ2Vals |         0.00324 |
# |         MaxQ2Vals |          -0.543 |
# |         MinQ2Vals |          -0.556 |
# |      AverageLogPi |          -0.139 |
# |          StdLogPi |           0.903 |
# |          MaxLogPi |           0.788 |
# |          MinLogPi |           -6.32 |
# |            LossPi |           0.549 |
# |             LossQ |           0.178 |
# |              Time |            1.22 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.494 |
# |           asset_1 |           0.506 |
# |             Epoch |               5 |
# |      AverageEpRet |           0.165 |
# |          StdEpRet |           0.073 |
# |          MaxEpRet |           0.238 |
# |          MinEpRet |          0.0918 |
# |  AverageTestEpRet |             0.2 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |             0.2 |
# |      MinTestEpRet |             0.2 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             319 |
# |     AverageQ1Vals |          -0.211 |
# |         StdQ1Vals |          0.0215 |
# |         MaxQ1Vals |          -0.179 |
# |         MinQ1Vals |          -0.268 |
# |     AverageQ2Vals |          -0.542 |
# |         StdQ2Vals |         0.00115 |
# |         MaxQ2Vals |          -0.539 |
# |         MinQ2Vals |          -0.543 |
# |      AverageLogPi |          -0.149 |
# |          StdLogPi |           0.918 |
# |          MaxLogPi |           0.788 |
# |          MinLogPi |           -7.68 |
# |            LossPi |           0.541 |
# |             LossQ |           0.126 |
# |              Time |            1.76 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.503 |
# |           asset_1 |           0.497 |
# |             Epoch |               6 |
# |      AverageEpRet |          0.0766 |
# |          StdEpRet |           0.115 |
# |          MaxEpRet |           0.192 |
# |          MinEpRet |         -0.0388 |
# |  AverageTestEpRet |          0.0978 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0978 |
# |      MinTestEpRet |          0.0978 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             383 |
# |     AverageQ1Vals |          -0.318 |
# |         StdQ1Vals |          0.0427 |
# |         MaxQ1Vals |          -0.236 |
# |         MinQ1Vals |          -0.469 |
# |     AverageQ2Vals |          -0.532 |
# |         StdQ2Vals |         0.00381 |
# |         MaxQ2Vals |          -0.527 |
# |         MinQ2Vals |          -0.538 |
# |      AverageLogPi |          -0.151 |
# |          StdLogPi |           0.914 |
# |          MaxLogPi |           0.787 |
# |          MinLogPi |           -6.99 |
# |            LossPi |           0.531 |
# |             LossQ |          0.0653 |
# |              Time |            2.25 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.544 |
# |           asset_1 |           0.456 |
# |             Epoch |               7 |
# |      AverageEpRet |          0.0869 |
# |          StdEpRet |            0.15 |
# |          MaxEpRet |           0.237 |
# |          MinEpRet |          -0.063 |
# |  AverageTestEpRet |          0.0821 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0821 |
# |      MinTestEpRet |          0.0821 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             447 |
# |     AverageQ1Vals |          -0.439 |
# |         StdQ1Vals |          0.0484 |
# |         MaxQ1Vals |          -0.312 |
# |         MinQ1Vals |          -0.619 |
# |     AverageQ2Vals |          -0.525 |
# |         StdQ2Vals |         0.00255 |
# |         MaxQ2Vals |          -0.519 |
# |         MinQ2Vals |          -0.529 |
# |      AverageLogPi |          -0.172 |
# |          StdLogPi |           0.928 |
# |          MaxLogPi |           0.789 |
# |          MinLogPi |           -6.93 |
# |            LossPi |           0.527 |
# |             LossQ |          0.0267 |
# |              Time |            2.76 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.627 |
# |           asset_1 |           0.373 |
# |             Epoch |               8 |
# |      AverageEpRet |          0.0182 |
# |          StdEpRet |          0.0464 |
# |          MaxEpRet |          0.0646 |
# |          MinEpRet |         -0.0282 |
# |  AverageTestEpRet |           0.128 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.128 |
# |      MinTestEpRet |           0.128 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             511 |
# |     AverageQ1Vals |          -0.496 |
# |         StdQ1Vals |          0.0502 |
# |         MaxQ1Vals |           -0.33 |
# |         MinQ1Vals |          -0.654 |
# |     AverageQ2Vals |          -0.517 |
# |         StdQ2Vals |         0.00185 |
# |         MaxQ2Vals |          -0.511 |
# |         MinQ2Vals |          -0.519 |
# |      AverageLogPi |           -0.15 |
# |          StdLogPi |           0.904 |
# |          MaxLogPi |           0.811 |
# |          MinLogPi |           -8.39 |
# |            LossPi |           0.529 |
# |             LossQ |          0.0209 |
# |              Time |            3.28 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.681 |
# |           asset_1 |           0.319 |
# |             Epoch |               9 |
# |      AverageEpRet |           0.106 |
# |          StdEpRet |         0.00611 |
# |          MaxEpRet |           0.112 |
# |          MinEpRet |          0.0998 |
# |  AverageTestEpRet |           0.137 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.137 |
# |      MinTestEpRet |           0.137 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             575 |
# |     AverageQ1Vals |          -0.499 |
# |         StdQ1Vals |          0.0504 |
# |         MaxQ1Vals |          -0.346 |
# |         MinQ1Vals |           -0.65 |
# |     AverageQ2Vals |          -0.508 |
# |         StdQ2Vals |         0.00248 |
# |         MaxQ2Vals |          -0.504 |
# |         MinQ2Vals |          -0.512 |
# |      AverageLogPi |          -0.134 |
# |          StdLogPi |           0.942 |
# |          MaxLogPi |           0.837 |
# |          MinLogPi |           -7.67 |
# |            LossPi |           0.523 |
# |             LossQ |          0.0197 |
# |              Time |             3.8 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.713 |
# |           asset_1 |           0.287 |
# |             Epoch |              10 |
# |      AverageEpRet |           0.118 |
# |          StdEpRet |          0.0219 |
# |          MaxEpRet |            0.14 |
# |          MinEpRet |          0.0965 |
# |  AverageTestEpRet |           0.056 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.056 |
# |      MinTestEpRet |           0.056 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             639 |
# |     AverageQ1Vals |          -0.495 |
# |         StdQ1Vals |          0.0476 |
# |         MaxQ1Vals |          -0.354 |
# |         MinQ1Vals |          -0.638 |
# |     AverageQ2Vals |          -0.504 |
# |         StdQ2Vals |         0.00312 |
# |         MaxQ2Vals |          -0.498 |
# |         MinQ2Vals |          -0.508 |
# |      AverageLogPi |         -0.0727 |
# |          StdLogPi |           0.885 |
# |          MaxLogPi |            0.86 |
# |          MinLogPi |           -6.53 |
# |            LossPi |           0.517 |
# |             LossQ |          0.0172 |
# |              Time |             4.3 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.739 |
# |           asset_1 |           0.261 |
# |             Epoch |              11 |
# |      AverageEpRet |          0.0511 |
# |          StdEpRet |          0.0498 |
# |          MaxEpRet |           0.101 |
# |          MinEpRet |          0.0013 |
# |  AverageTestEpRet |          0.0317 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0317 |
# |      MinTestEpRet |          0.0317 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             703 |
# |     AverageQ1Vals |          -0.489 |
# |         StdQ1Vals |          0.0431 |
# |         MaxQ1Vals |          -0.363 |
# |         MinQ1Vals |          -0.616 |
# |     AverageQ2Vals |          -0.494 |
# |         StdQ2Vals |          0.0024 |
# |         MaxQ2Vals |          -0.491 |
# |         MinQ2Vals |          -0.526 |
# |      AverageLogPi |         -0.0601 |
# |          StdLogPi |           0.916 |
# |          MaxLogPi |            0.88 |
# |          MinLogPi |            -6.4 |
# |            LossPi |           0.508 |
# |             LossQ |          0.0188 |
# |              Time |            4.81 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.758 |
# |           asset_1 |           0.242 |
# |             Epoch |              12 |
# |      AverageEpRet |           0.084 |
# |          StdEpRet |          0.0397 |
# |          MaxEpRet |           0.124 |
# |          MinEpRet |          0.0442 |
# |  AverageTestEpRet |          0.0603 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0603 |
# |      MinTestEpRet |          0.0603 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             767 |
# |     AverageQ1Vals |          -0.482 |
# |         StdQ1Vals |          0.0396 |
# |         MaxQ1Vals |          -0.367 |
# |         MinQ1Vals |          -0.604 |
# |     AverageQ2Vals |          -0.487 |
# |         StdQ2Vals |         0.00556 |
# |         MaxQ2Vals |          -0.483 |
# |         MinQ2Vals |          -0.533 |
# |      AverageLogPi |         -0.0563 |
# |          StdLogPi |           0.938 |
# |          MaxLogPi |           0.896 |
# |          MinLogPi |           -9.17 |
# |            LossPi |           0.498 |
# |             LossQ |          0.0168 |
# |              Time |             5.3 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.774 |
# |           asset_1 |           0.226 |
# |             Epoch |              13 |
# |      AverageEpRet |          0.0671 |
# |          StdEpRet |        0.000236 |
# |          MaxEpRet |          0.0673 |
# |          MinEpRet |          0.0669 |
# |  AverageTestEpRet |          0.0649 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0649 |
# |      MinTestEpRet |          0.0649 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             831 |
# |     AverageQ1Vals |          -0.475 |
# |         StdQ1Vals |          0.0358 |
# |         MaxQ1Vals |          -0.373 |
# |         MinQ1Vals |          -0.586 |
# |     AverageQ2Vals |           -0.48 |
# |         StdQ2Vals |         0.00367 |
# |         MaxQ2Vals |          -0.475 |
# |         MinQ2Vals |          -0.512 |
# |      AverageLogPi |         -0.0464 |
# |          StdLogPi |           0.948 |
# |          MaxLogPi |           0.909 |
# |          MinLogPi |            -9.1 |
# |            LossPi |            0.49 |
# |             LossQ |          0.0167 |
# |              Time |            5.81 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.787 |
# |           asset_1 |           0.213 |
# |             Epoch |              14 |
# |      AverageEpRet |          0.0977 |
# |          StdEpRet |          0.0342 |
# |          MaxEpRet |           0.132 |
# |          MinEpRet |          0.0635 |
# |  AverageTestEpRet |          0.0311 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0311 |
# |      MinTestEpRet |          0.0311 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             895 |
# |     AverageQ1Vals |          -0.469 |
# |         StdQ1Vals |          0.0323 |
# |         MaxQ1Vals |          -0.378 |
# |         MinQ1Vals |           -0.57 |
# |     AverageQ2Vals |          -0.473 |
# |         StdQ2Vals |         0.00399 |
# |         MaxQ2Vals |          -0.467 |
# |         MinQ2Vals |          -0.501 |
# |      AverageLogPi |         -0.0265 |
# |          StdLogPi |           0.941 |
# |          MaxLogPi |           0.921 |
# |          MinLogPi |           -7.77 |
# |            LossPi |           0.482 |
# |             LossQ |          0.0162 |
# |              Time |            6.33 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.798 |
# |           asset_1 |           0.202 |
# |             Epoch |              15 |
# |      AverageEpRet |          0.0643 |
# |          StdEpRet |          0.0243 |
# |          MaxEpRet |          0.0886 |
# |          MinEpRet |            0.04 |
# |  AverageTestEpRet |           0.115 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.115 |
# |      MinTestEpRet |           0.115 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |             959 |
# |     AverageQ1Vals |          -0.463 |
# |         StdQ1Vals |          0.0294 |
# |         MaxQ1Vals |          -0.376 |
# |         MinQ1Vals |          -0.551 |
# |     AverageQ2Vals |          -0.467 |
# |         StdQ2Vals |         0.00358 |
# |         MaxQ2Vals |          -0.464 |
# |         MinQ2Vals |          -0.497 |
# |      AverageLogPi |         -0.0219 |
# |          StdLogPi |           0.916 |
# |          MaxLogPi |           0.934 |
# |          MinLogPi |           -5.63 |
# |            LossPi |           0.475 |
# |             LossQ |          0.0156 |
# |              Time |            6.85 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.807 |
# |           asset_1 |           0.193 |
# |             Epoch |              16 |
# |      AverageEpRet |          0.0866 |
# |          StdEpRet |         0.00273 |
# |          MaxEpRet |          0.0893 |
# |          MinEpRet |          0.0839 |
# |  AverageTestEpRet |          0.0371 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0371 |
# |      MinTestEpRet |          0.0371 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.02e+03 |
# |     AverageQ1Vals |          -0.459 |
# |         StdQ1Vals |          0.0267 |
# |         MaxQ1Vals |          -0.376 |
# |         MinQ1Vals |          -0.546 |
# |     AverageQ2Vals |          -0.462 |
# |         StdQ2Vals |         0.00437 |
# |         MaxQ2Vals |          -0.457 |
# |         MinQ2Vals |          -0.493 |
# |      AverageLogPi |         -0.0155 |
# |          StdLogPi |           0.932 |
# |          MaxLogPi |           0.942 |
# |          MinLogPi |           -7.56 |
# |            LossPi |            0.47 |
# |             LossQ |          0.0147 |
# |              Time |            7.34 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.812 |
# |           asset_1 |           0.188 |
# |             Epoch |              17 |
# |      AverageEpRet |          0.0714 |
# |          StdEpRet |          0.0485 |
# |          MaxEpRet |            0.12 |
# |          MinEpRet |          0.0229 |
# |  AverageTestEpRet |           0.132 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.132 |
# |      MinTestEpRet |           0.132 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.09e+03 |
# |     AverageQ1Vals |          -0.454 |
# |         StdQ1Vals |          0.0233 |
# |         MaxQ1Vals |          -0.378 |
# |         MinQ1Vals |           -0.53 |
# |     AverageQ2Vals |          -0.456 |
# |         StdQ2Vals |         0.00366 |
# |         MaxQ2Vals |          -0.452 |
# |         MinQ2Vals |          -0.486 |
# |      AverageLogPi |         -0.0175 |
# |          StdLogPi |           0.964 |
# |          MaxLogPi |           0.947 |
# |          MinLogPi |           -7.52 |
# |            LossPi |           0.463 |
# |             LossQ |          0.0142 |
# |              Time |            7.86 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.815 |
# |           asset_1 |           0.185 |
# |             Epoch |              18 |
# |      AverageEpRet |          0.0295 |
# |          StdEpRet |          0.0333 |
# |          MaxEpRet |          0.0628 |
# |          MinEpRet |        -0.00375 |
# |  AverageTestEpRet |          0.0628 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0628 |
# |      MinTestEpRet |          0.0628 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.15e+03 |
# |     AverageQ1Vals |           -0.45 |
# |         StdQ1Vals |          0.0209 |
# |         MaxQ1Vals |          -0.382 |
# |         MinQ1Vals |          -0.516 |
# |     AverageQ2Vals |          -0.453 |
# |         StdQ2Vals |         0.00277 |
# |         MaxQ2Vals |           -0.45 |
# |         MinQ2Vals |          -0.482 |
# |      AverageLogPi |        -0.00872 |
# |          StdLogPi |           0.943 |
# |          MaxLogPi |            0.95 |
# |          MinLogPi |           -7.19 |
# |            LossPi |           0.459 |
# |             LossQ |          0.0132 |
# |              Time |            8.39 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.814 |
# |           asset_1 |           0.186 |
# |             Epoch |              19 |
# |      AverageEpRet |          0.0494 |
# |          StdEpRet |          0.0294 |
# |          MaxEpRet |          0.0787 |
# |          MinEpRet |            0.02 |
# |  AverageTestEpRet |           0.109 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.109 |
# |      MinTestEpRet |           0.109 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.22e+03 |
# |     AverageQ1Vals |          -0.446 |
# |         StdQ1Vals |          0.0191 |
# |         MaxQ1Vals |          -0.386 |
# |         MinQ1Vals |          -0.506 |
# |     AverageQ2Vals |          -0.447 |
# |         StdQ2Vals |         0.00331 |
# |         MaxQ2Vals |          -0.442 |
# |         MinQ2Vals |          -0.477 |
# |      AverageLogPi |         0.00326 |
# |          StdLogPi |           0.918 |
# |          MaxLogPi |           0.951 |
# |          MinLogPi |           -5.73 |
# |            LossPi |           0.453 |
# |             LossQ |          0.0136 |
# |              Time |            8.89 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.812 |
# |           asset_1 |           0.188 |
# |             Epoch |              20 |
# |      AverageEpRet |          0.0918 |
# |          StdEpRet |        0.000792 |
# |          MaxEpRet |          0.0925 |
# |          MinEpRet |           0.091 |
# |  AverageTestEpRet |           0.111 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.111 |
# |      MinTestEpRet |           0.111 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.28e+03 |
# |     AverageQ1Vals |           -0.44 |
# |         StdQ1Vals |          0.0169 |
# |         MaxQ1Vals |          -0.389 |
# |         MinQ1Vals |          -0.494 |
# |     AverageQ2Vals |           -0.44 |
# |         StdQ2Vals |         0.00356 |
# |         MaxQ2Vals |          -0.437 |
# |         MinQ2Vals |          -0.468 |
# |      AverageLogPi |         -0.0172 |
# |          StdLogPi |            0.96 |
# |          MaxLogPi |            0.95 |
# |          MinLogPi |           -7.18 |
# |            LossPi |           0.446 |
# |             LossQ |           0.014 |
# |              Time |            9.41 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.809 |
# |           asset_1 |           0.191 |
# |             Epoch |              21 |
# |      AverageEpRet |          0.0838 |
# |          StdEpRet |           0.028 |
# |          MaxEpRet |           0.112 |
# |          MinEpRet |          0.0559 |
# |  AverageTestEpRet |          0.0713 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0713 |
# |      MinTestEpRet |          0.0713 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.34e+03 |
# |     AverageQ1Vals |          -0.435 |
# |         StdQ1Vals |          0.0146 |
# |         MaxQ1Vals |           -0.39 |
# |         MinQ1Vals |          -0.481 |
# |     AverageQ2Vals |          -0.435 |
# |         StdQ2Vals |         0.00292 |
# |         MaxQ2Vals |          -0.433 |
# |         MinQ2Vals |          -0.463 |
# |      AverageLogPi |          -0.023 |
# |          StdLogPi |           0.947 |
# |          MaxLogPi |           0.948 |
# |          MinLogPi |           -6.08 |
# |            LossPi |            0.44 |
# |             LossQ |          0.0134 |
# |              Time |             9.9 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.804 |
# |           asset_1 |           0.196 |
# |             Epoch |              22 |
# |      AverageEpRet |           0.105 |
# |          StdEpRet |          0.0015 |
# |          MaxEpRet |           0.106 |
# |          MinEpRet |           0.103 |
# |  AverageTestEpRet |        -0.00926 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |        -0.00926 |
# |      MinTestEpRet |        -0.00926 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.41e+03 |
# |     AverageQ1Vals |           -0.43 |
# |         StdQ1Vals |          0.0128 |
# |         MaxQ1Vals |           -0.39 |
# |         MinQ1Vals |          -0.472 |
# |     AverageQ2Vals |          -0.431 |
# |         StdQ2Vals |         0.00337 |
# |         MaxQ2Vals |          -0.427 |
# |         MinQ2Vals |          -0.457 |
# |      AverageLogPi |        -0.00912 |
# |          StdLogPi |           0.925 |
# |          MaxLogPi |           0.944 |
# |          MinLogPi |            -6.6 |
# |            LossPi |           0.435 |
# |             LossQ |          0.0124 |
# |              Time |            10.4 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.795 |
# |           asset_1 |           0.205 |
# |             Epoch |              23 |
# |      AverageEpRet |          0.0284 |
# |          StdEpRet |          0.0128 |
# |          MaxEpRet |          0.0411 |
# |          MinEpRet |          0.0156 |
# |  AverageTestEpRet |          0.0304 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0304 |
# |      MinTestEpRet |          0.0304 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.47e+03 |
# |     AverageQ1Vals |          -0.427 |
# |         StdQ1Vals |           0.011 |
# |         MaxQ1Vals |          -0.392 |
# |         MinQ1Vals |          -0.464 |
# |     AverageQ2Vals |          -0.427 |
# |         StdQ2Vals |         0.00361 |
# |         MaxQ2Vals |          -0.421 |
# |         MinQ2Vals |          -0.453 |
# |      AverageLogPi |         -0.0163 |
# |          StdLogPi |           0.939 |
# |          MaxLogPi |            0.94 |
# |          MinLogPi |           -7.75 |
# |            LossPi |           0.431 |
# |             LossQ |          0.0112 |
# |              Time |            10.9 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.786 |
# |           asset_1 |           0.214 |
# |             Epoch |              24 |
# |      AverageEpRet |            0.12 |
# |          StdEpRet |         0.00134 |
# |          MaxEpRet |           0.121 |
# |          MinEpRet |           0.118 |
# |  AverageTestEpRet |           0.123 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.123 |
# |      MinTestEpRet |           0.123 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.54e+03 |
# |     AverageQ1Vals |          -0.421 |
# |         StdQ1Vals |         0.00927 |
# |         MaxQ1Vals |          -0.393 |
# |         MinQ1Vals |          -0.451 |
# |     AverageQ2Vals |          -0.421 |
# |         StdQ2Vals |         0.00319 |
# |         MaxQ2Vals |          -0.417 |
# |         MinQ2Vals |          -0.447 |
# |      AverageLogPi |         -0.0245 |
# |          StdLogPi |           0.949 |
# |          MaxLogPi |           0.931 |
# |          MinLogPi |           -6.64 |
# |            LossPi |           0.425 |
# |             LossQ |          0.0116 |
# |              Time |            11.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.775 |
# |           asset_1 |           0.225 |
# |             Epoch |              25 |
# |      AverageEpRet |          0.0951 |
# |          StdEpRet |          0.0105 |
# |          MaxEpRet |           0.106 |
# |          MinEpRet |          0.0846 |
# |  AverageTestEpRet |          0.0326 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0326 |
# |      MinTestEpRet |          0.0326 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         1.6e+03 |
# |     AverageQ1Vals |          -0.416 |
# |         StdQ1Vals |         0.00785 |
# |         MaxQ1Vals |          -0.391 |
# |         MinQ1Vals |          -0.442 |
# |     AverageQ2Vals |          -0.415 |
# |         StdQ2Vals |         0.00276 |
# |         MaxQ2Vals |          -0.412 |
# |         MinQ2Vals |          -0.443 |
# |      AverageLogPi |           -0.05 |
# |          StdLogPi |           0.947 |
# |          MaxLogPi |           0.922 |
# |          MinLogPi |            -7.1 |
# |            LossPi |           0.418 |
# |             LossQ |          0.0121 |
# |              Time |              12 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.763 |
# |           asset_1 |           0.237 |
# |             Epoch |              26 |
# |      AverageEpRet |          0.0932 |
# |          StdEpRet |          0.0366 |
# |          MaxEpRet |            0.13 |
# |          MinEpRet |          0.0566 |
# |  AverageTestEpRet |          0.0714 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0714 |
# |      MinTestEpRet |          0.0714 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.66e+03 |
# |     AverageQ1Vals |          -0.411 |
# |         StdQ1Vals |         0.00629 |
# |         MaxQ1Vals |          -0.391 |
# |         MinQ1Vals |          -0.432 |
# |     AverageQ2Vals |          -0.412 |
# |         StdQ2Vals |         0.00168 |
# |         MaxQ2Vals |          -0.409 |
# |         MinQ2Vals |           -0.43 |
# |      AverageLogPi |         -0.0461 |
# |          StdLogPi |            0.92 |
# |          MaxLogPi |            0.91 |
# |          MinLogPi |           -6.39 |
# |            LossPi |           0.414 |
# |             LossQ |         0.00977 |
# |              Time |            12.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.749 |
# |           asset_1 |           0.251 |
# |             Epoch |              27 |
# |      AverageEpRet |           0.271 |
# |          StdEpRet |          0.0828 |
# |          MaxEpRet |           0.354 |
# |          MinEpRet |           0.188 |
# |  AverageTestEpRet |           0.077 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.077 |
# |      MinTestEpRet |           0.077 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.73e+03 |
# |     AverageQ1Vals |          -0.406 |
# |         StdQ1Vals |         0.00551 |
# |         MaxQ1Vals |          -0.389 |
# |         MinQ1Vals |          -0.426 |
# |     AverageQ2Vals |          -0.405 |
# |         StdQ2Vals |         0.00322 |
# |         MaxQ2Vals |          -0.401 |
# |         MinQ2Vals |          -0.429 |
# |      AverageLogPi |         -0.0601 |
# |          StdLogPi |           0.926 |
# |          MaxLogPi |           0.899 |
# |          MinLogPi |           -5.43 |
# |            LossPi |           0.408 |
# |             LossQ |          0.0106 |
# |              Time |              13 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.736 |
# |           asset_1 |           0.264 |
# |             Epoch |              28 |
# |      AverageEpRet |           0.116 |
# |          StdEpRet |          0.0324 |
# |          MaxEpRet |           0.148 |
# |          MinEpRet |          0.0835 |
# |  AverageTestEpRet |          0.0999 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0999 |
# |      MinTestEpRet |          0.0999 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.79e+03 |
# |     AverageQ1Vals |            -0.4 |
# |         StdQ1Vals |         0.00422 |
# |         MaxQ1Vals |          -0.387 |
# |         MinQ1Vals |          -0.416 |
# |     AverageQ2Vals |          -0.399 |
# |         StdQ2Vals |         0.00232 |
# |         MaxQ2Vals |          -0.396 |
# |         MinQ2Vals |          -0.422 |
# |      AverageLogPi |         -0.0508 |
# |          StdLogPi |           0.922 |
# |          MaxLogPi |           0.889 |
# |          MinLogPi |           -6.68 |
# |            LossPi |           0.401 |
# |             LossQ |           0.011 |
# |              Time |            13.5 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.726 |
# |           asset_1 |           0.274 |
# |             Epoch |              29 |
# |      AverageEpRet |          0.0351 |
# |          StdEpRet |          0.0118 |
# |          MaxEpRet |          0.0469 |
# |          MinEpRet |          0.0233 |
# |  AverageTestEpRet |         0.00762 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |         0.00762 |
# |      MinTestEpRet |         0.00762 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.86e+03 |
# |     AverageQ1Vals |          -0.393 |
# |         StdQ1Vals |         0.00354 |
# |         MaxQ1Vals |          -0.383 |
# |         MinQ1Vals |          -0.406 |
# |     AverageQ2Vals |          -0.391 |
# |         StdQ2Vals |         0.00292 |
# |         MaxQ2Vals |          -0.388 |
# |         MinQ2Vals |          -0.409 |
# |      AverageLogPi |         -0.0653 |
# |          StdLogPi |           0.937 |
# |          MaxLogPi |           0.876 |
# |          MinLogPi |            -6.3 |
# |            LossPi |           0.393 |
# |             LossQ |          0.0116 |
# |              Time |            14.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.721 |
# |           asset_1 |           0.279 |
# |             Epoch |              30 |
# |      AverageEpRet |           0.057 |
# |          StdEpRet |          0.0261 |
# |          MaxEpRet |          0.0831 |
# |          MinEpRet |          0.0309 |
# |  AverageTestEpRet |           0.058 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.058 |
# |      MinTestEpRet |           0.058 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.92e+03 |
# |     AverageQ1Vals |          -0.389 |
# |         StdQ1Vals |         0.00264 |
# |         MaxQ1Vals |          -0.382 |
# |         MinQ1Vals |          -0.397 |
# |     AverageQ2Vals |          -0.388 |
# |         StdQ2Vals |          0.0037 |
# |         MaxQ2Vals |          -0.383 |
# |         MinQ2Vals |          -0.406 |
# |      AverageLogPi |         -0.0583 |
# |          StdLogPi |           0.899 |
# |          MaxLogPi |           0.871 |
# |          MinLogPi |           -6.66 |
# |            LossPi |           0.389 |
# |             LossQ |         0.00976 |
# |              Time |            14.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.714 |
# |           asset_1 |           0.286 |
# |             Epoch |              31 |
# |      AverageEpRet |           0.117 |
# |          StdEpRet |          0.0347 |
# |          MaxEpRet |           0.151 |
# |          MinEpRet |          0.0819 |
# |  AverageTestEpRet |         -0.0138 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |         -0.0138 |
# |      MinTestEpRet |         -0.0138 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        1.98e+03 |
# |     AverageQ1Vals |          -0.384 |
# |         StdQ1Vals |          0.0023 |
# |         MaxQ1Vals |          -0.377 |
# |         MinQ1Vals |           -0.39 |
# |     AverageQ2Vals |          -0.382 |
# |         StdQ2Vals |         0.00328 |
# |         MaxQ2Vals |          -0.377 |
# |         MinQ2Vals |          -0.392 |
# |      AverageLogPi |         -0.0569 |
# |          StdLogPi |           0.899 |
# |          MaxLogPi |           0.867 |
# |          MinLogPi |           -6.54 |
# |            LossPi |           0.384 |
# |             LossQ |         0.00984 |
# |              Time |            15.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.707 |
# |           asset_1 |           0.293 |
# |             Epoch |              32 |
# |      AverageEpRet |          0.0925 |
# |          StdEpRet |          0.0633 |
# |          MaxEpRet |           0.156 |
# |          MinEpRet |          0.0292 |
# |  AverageTestEpRet |           0.149 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.149 |
# |      MinTestEpRet |           0.149 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.05e+03 |
# |     AverageQ1Vals |          -0.377 |
# |         StdQ1Vals |         0.00183 |
# |         MaxQ1Vals |          -0.372 |
# |         MinQ1Vals |          -0.382 |
# |     AverageQ2Vals |          -0.376 |
# |         StdQ2Vals |         0.00181 |
# |         MaxQ2Vals |          -0.374 |
# |         MinQ2Vals |          -0.384 |
# |      AverageLogPi |         -0.0967 |
# |          StdLogPi |           0.936 |
# |          MaxLogPi |           0.862 |
# |          MinLogPi |           -7.85 |
# |            LossPi |           0.377 |
# |             LossQ |         0.00955 |
# |              Time |            15.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.695 |
# |           asset_1 |           0.305 |
# |             Epoch |              33 |
# |      AverageEpRet |          0.0832 |
# |          StdEpRet |          0.0786 |
# |          MaxEpRet |           0.162 |
# |          MinEpRet |         0.00455 |
# |  AverageTestEpRet |           0.151 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.151 |
# |      MinTestEpRet |           0.151 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.11e+03 |
# |     AverageQ1Vals |          -0.371 |
# |         StdQ1Vals |         0.00228 |
# |         MaxQ1Vals |          -0.363 |
# |         MinQ1Vals |          -0.378 |
# |     AverageQ2Vals |          -0.369 |
# |         StdQ2Vals |         0.00188 |
# |         MaxQ2Vals |          -0.367 |
# |         MinQ2Vals |          -0.383 |
# |      AverageLogPi |         -0.0889 |
# |          StdLogPi |           0.938 |
# |          MaxLogPi |           0.856 |
# |          MinLogPi |           -8.52 |
# |            LossPi |           0.371 |
# |             LossQ |          0.0101 |
# |              Time |            16.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.679 |
# |           asset_1 |           0.321 |
# |             Epoch |              34 |
# |      AverageEpRet |          0.0345 |
# |          StdEpRet |          0.0313 |
# |          MaxEpRet |          0.0658 |
# |          MinEpRet |         0.00316 |
# |  AverageTestEpRet |           0.127 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.127 |
# |      MinTestEpRet |           0.127 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.18e+03 |
# |     AverageQ1Vals |          -0.366 |
# |         StdQ1Vals |         0.00223 |
# |         MaxQ1Vals |          -0.357 |
# |         MinQ1Vals |          -0.373 |
# |     AverageQ2Vals |          -0.364 |
# |         StdQ2Vals |         0.00179 |
# |         MaxQ2Vals |          -0.362 |
# |         MinQ2Vals |          -0.374 |
# |      AverageLogPi |          -0.099 |
# |          StdLogPi |            0.93 |
# |          MaxLogPi |           0.849 |
# |          MinLogPi |           -8.98 |
# |            LossPi |           0.366 |
# |             LossQ |         0.00873 |
# |              Time |            16.6 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.669 |
# |           asset_1 |           0.331 |
# |             Epoch |              35 |
# |      AverageEpRet |          0.0143 |
# |          StdEpRet |         0.00157 |
# |          MaxEpRet |          0.0158 |
# |          MinEpRet |          0.0127 |
# |  AverageTestEpRet |           0.116 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.116 |
# |      MinTestEpRet |           0.116 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.24e+03 |
# |     AverageQ1Vals |           -0.36 |
# |         StdQ1Vals |          0.0028 |
# |         MaxQ1Vals |          -0.349 |
# |         MinQ1Vals |          -0.368 |
# |     AverageQ2Vals |          -0.359 |
# |         StdQ2Vals |         0.00234 |
# |         MaxQ2Vals |          -0.356 |
# |         MinQ2Vals |          -0.371 |
# |      AverageLogPi |          -0.105 |
# |          StdLogPi |            0.93 |
# |          MaxLogPi |           0.839 |
# |          MinLogPi |           -8.77 |
# |            LossPi |            0.36 |
# |             LossQ |         0.00873 |
# |              Time |            17.1 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.656 |
# |           asset_1 |           0.344 |
# |             Epoch |              36 |
# |      AverageEpRet |          0.0901 |
# |          StdEpRet |          0.0608 |
# |          MaxEpRet |           0.151 |
# |          MinEpRet |          0.0293 |
# |  AverageTestEpRet |          0.0553 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0553 |
# |      MinTestEpRet |          0.0553 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.3e+03 |
# |     AverageQ1Vals |          -0.356 |
# |         StdQ1Vals |         0.00326 |
# |         MaxQ1Vals |          -0.344 |
# |         MinQ1Vals |          -0.365 |
# |     AverageQ2Vals |          -0.354 |
# |         StdQ2Vals |         0.00339 |
# |         MaxQ2Vals |           -0.35 |
# |         MinQ2Vals |          -0.369 |
# |      AverageLogPi |          -0.117 |
# |          StdLogPi |           0.933 |
# |          MaxLogPi |           0.833 |
# |          MinLogPi |           -7.73 |
# |            LossPi |           0.356 |
# |             LossQ |         0.00862 |
# |              Time |            17.7 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.65 |
# |           asset_1 |            0.35 |
# |             Epoch |              37 |
# |      AverageEpRet |          0.0993 |
# |          StdEpRet |          0.0687 |
# |          MaxEpRet |           0.168 |
# |          MinEpRet |          0.0306 |
# |  AverageTestEpRet |          0.0058 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0058 |
# |      MinTestEpRet |          0.0058 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.37e+03 |
# |     AverageQ1Vals |           -0.35 |
# |         StdQ1Vals |         0.00292 |
# |         MaxQ1Vals |          -0.341 |
# |         MinQ1Vals |           -0.36 |
# |     AverageQ2Vals |          -0.349 |
# |         StdQ2Vals |         0.00122 |
# |         MaxQ2Vals |          -0.347 |
# |         MinQ2Vals |          -0.362 |
# |      AverageLogPi |          -0.106 |
# |          StdLogPi |           0.918 |
# |          MaxLogPi |           0.826 |
# |          MinLogPi |            -8.5 |
# |            LossPi |           0.351 |
# |             LossQ |         0.00788 |
# |              Time |            18.2 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.653 |
# |           asset_1 |           0.347 |
# |             Epoch |              38 |
# |      AverageEpRet |           0.152 |
# |          StdEpRet |          0.0327 |
# |          MaxEpRet |           0.184 |
# |          MinEpRet |           0.119 |
# |  AverageTestEpRet |           0.139 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.139 |
# |      MinTestEpRet |           0.139 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.43e+03 |
# |     AverageQ1Vals |          -0.346 |
# |         StdQ1Vals |         0.00325 |
# |         MaxQ1Vals |          -0.334 |
# |         MinQ1Vals |          -0.357 |
# |     AverageQ2Vals |          -0.344 |
# |         StdQ2Vals |         0.00185 |
# |         MaxQ2Vals |          -0.341 |
# |         MinQ2Vals |          -0.361 |
# |      AverageLogPi |          -0.125 |
# |          StdLogPi |           0.917 |
# |          MaxLogPi |           0.826 |
# |          MinLogPi |             -10 |
# |            LossPi |           0.346 |
# |             LossQ |         0.00813 |
# |              Time |            18.7 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |           0.664 |
# |           asset_1 |           0.336 |
# |             Epoch |              39 |
# |      AverageEpRet |           0.128 |
# |          StdEpRet |          0.0268 |
# |          MaxEpRet |           0.155 |
# |          MinEpRet |           0.101 |
# |  AverageTestEpRet |           0.142 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.142 |
# |      MinTestEpRet |           0.142 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.5e+03 |
# |     AverageQ1Vals |          -0.341 |
# |         StdQ1Vals |         0.00295 |
# |         MaxQ1Vals |          -0.331 |
# |         MinQ1Vals |          -0.352 |
# |     AverageQ2Vals |           -0.34 |
# |         StdQ2Vals |         0.00115 |
# |         MaxQ2Vals |          -0.338 |
# |         MinQ2Vals |          -0.353 |
# |      AverageLogPi |          -0.105 |
# |          StdLogPi |           0.911 |
# |          MaxLogPi |            0.83 |
# |          MinLogPi |           -6.55 |
# |            LossPi |           0.342 |
# |             LossQ |         0.00693 |
# |              Time |            19.2 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.68 |
# |           asset_1 |            0.32 |
# |             Epoch |              40 |
# |      AverageEpRet |           0.135 |
# |          StdEpRet |          0.0841 |
# |          MaxEpRet |           0.219 |
# |          MinEpRet |          0.0511 |
# |  AverageTestEpRet |         -0.0216 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |         -0.0216 |
# |      MinTestEpRet |         -0.0216 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.56e+03 |
# |     AverageQ1Vals |          -0.336 |
# |         StdQ1Vals |         0.00332 |
# |         MaxQ1Vals |          -0.324 |
# ...
# |             Epoch |             388 |
# |      AverageEpRet |          0.0915 |
# |          StdEpRet |           0.121 |
# |          MaxEpRet |           0.213 |
# |          MinEpRet |         -0.0296 |
# |  AverageTestEpRet |           0.241 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.241 |
# |      MinTestEpRet |           0.241 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.48e+04 |
# |     AverageQ1Vals |          0.0894 |
# |         StdQ1Vals |         0.00246 |
# |         MaxQ1Vals |          0.0975 |
# |         MinQ1Vals |          0.0812 |
# |     AverageQ2Vals |          0.0893 |
# |         StdQ2Vals |        0.000698 |
# |         MaxQ2Vals |          0.0907 |
# |         MinQ2Vals |          0.0881 |
# |      AverageLogPi |            0.15 |
# |          StdLogPi |           0.964 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -6.48 |
# |            LossPi |         -0.0889 |
# |             LossQ |        0.000529 |
# |              Time |             201 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0594 |
# |           asset_1 |           0.941 |
# |             Epoch |             389 |
# |      AverageEpRet |           0.204 |
# |          StdEpRet |          0.0577 |
# |          MaxEpRet |           0.262 |
# |          MinEpRet |           0.146 |
# |  AverageTestEpRet |          0.0823 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0823 |
# |      MinTestEpRet |          0.0823 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.49e+04 |
# |     AverageQ1Vals |          0.0897 |
# |         StdQ1Vals |         0.00263 |
# |         MaxQ1Vals |          0.0987 |
# |         MinQ1Vals |          0.0813 |
# |     AverageQ2Vals |          0.0898 |
# |         StdQ2Vals |        0.000974 |
# |         MaxQ2Vals |          0.0918 |
# |         MinQ2Vals |          0.0881 |
# |      AverageLogPi |           0.157 |
# |          StdLogPi |           0.926 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -6.71 |
# |            LossPi |         -0.0893 |
# |             LossQ |        0.000484 |
# |              Time |             201 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0615 |
# |           asset_1 |           0.939 |
# |             Epoch |             390 |
# |      AverageEpRet |          0.0235 |
# |          StdEpRet |          0.0662 |
# |          MaxEpRet |          0.0898 |
# |          MinEpRet |         -0.0427 |
# |  AverageTestEpRet |            0.28 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |            0.28 |
# |      MinTestEpRet |            0.28 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.5e+04 |
# |     AverageQ1Vals |          0.0902 |
# |         StdQ1Vals |         0.00245 |
# |         MaxQ1Vals |          0.0978 |
# |         MinQ1Vals |          0.0797 |
# |     AverageQ2Vals |          0.0901 |
# |         StdQ2Vals |        0.000683 |
# |         MaxQ2Vals |          0.0914 |
# |         MinQ2Vals |          0.0888 |
# |      AverageLogPi |           0.139 |
# |          StdLogPi |           0.933 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -5.85 |
# |            LossPi |         -0.0897 |
# |             LossQ |        0.000466 |
# |              Time |             202 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0605 |
# |           asset_1 |            0.94 |
# |             Epoch |             391 |
# |      AverageEpRet |            0.21 |
# |          StdEpRet |           0.065 |
# |          MaxEpRet |           0.275 |
# |          MinEpRet |           0.145 |
# |  AverageTestEpRet |           0.142 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.142 |
# |      MinTestEpRet |           0.142 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |         2.5e+04 |
# |     AverageQ1Vals |          0.0904 |
# |         StdQ1Vals |         0.00253 |
# |         MaxQ1Vals |          0.0979 |
# |         MinQ1Vals |          0.0801 |
# |     AverageQ2Vals |          0.0903 |
# |         StdQ2Vals |        0.000635 |
# |         MaxQ2Vals |          0.0915 |
# |         MinQ2Vals |          0.0892 |
# |      AverageLogPi |           0.141 |
# |          StdLogPi |           0.957 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -6.32 |
# |            LossPi |         -0.0899 |
# |             LossQ |        0.000477 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0613 |
# |           asset_1 |           0.939 |
# |             Epoch |             392 |
# |      AverageEpRet |           0.163 |
# |          StdEpRet |          0.0202 |
# |          MaxEpRet |           0.183 |
# |          MinEpRet |           0.143 |
# |  AverageTestEpRet |           0.192 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.192 |
# |      MinTestEpRet |           0.192 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.51e+04 |
# |     AverageQ1Vals |          0.0901 |
# |         StdQ1Vals |         0.00249 |
# |         MaxQ1Vals |          0.0978 |
# |         MinQ1Vals |          0.0796 |
# |     AverageQ2Vals |          0.0901 |
# |         StdQ2Vals |        0.000665 |
# |         MaxQ2Vals |          0.0912 |
# |         MinQ2Vals |          0.0889 |
# |      AverageLogPi |           0.135 |
# |          StdLogPi |           0.964 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -8.14 |
# |            LossPi |         -0.0896 |
# |             LossQ |        0.000533 |
# |              Time |             203 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |            0.06 |
# |           asset_1 |            0.94 |
# |             Epoch |             393 |
# |      AverageEpRet |           0.383 |
# |          StdEpRet |           0.156 |
# |          MaxEpRet |           0.539 |
# |          MinEpRet |           0.227 |
# |  AverageTestEpRet |           0.135 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.135 |
# |      MinTestEpRet |           0.135 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.52e+04 |
# |     AverageQ1Vals |          0.0901 |
# |         StdQ1Vals |         0.00269 |
# |         MaxQ1Vals |          0.0984 |
# |         MinQ1Vals |          0.0808 |
# |     AverageQ2Vals |          0.0901 |
# |         StdQ2Vals |        0.000711 |
# |         MaxQ2Vals |          0.0914 |
# |         MinQ2Vals |          0.0888 |
# |      AverageLogPi |           0.154 |
# |          StdLogPi |           0.965 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -7.14 |
# |            LossPi |         -0.0895 |
# |             LossQ |         0.00056 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0583 |
# |           asset_1 |           0.942 |
# |             Epoch |             394 |
# |      AverageEpRet |         -0.0251 |
# |          StdEpRet |           0.188 |
# |          MaxEpRet |           0.163 |
# |          MinEpRet |          -0.213 |
# |  AverageTestEpRet |           0.219 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.219 |
# |      MinTestEpRet |           0.219 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.52e+04 |
# |     AverageQ1Vals |          0.0899 |
# |         StdQ1Vals |         0.00266 |
# |         MaxQ1Vals |          0.0983 |
# |         MinQ1Vals |          0.0806 |
# |     AverageQ2Vals |          0.0899 |
# |         StdQ2Vals |        0.000662 |
# |         MaxQ2Vals |          0.0916 |
# |         MinQ2Vals |          0.0888 |
# |      AverageLogPi |           0.134 |
# |          StdLogPi |           0.952 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -7.39 |
# |            LossPi |         -0.0894 |
# |             LossQ |        0.000569 |
# |              Time |             204 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0572 |
# |           asset_1 |           0.943 |
# |             Epoch |             395 |
# |      AverageEpRet |           0.261 |
# |          StdEpRet |          0.0254 |
# |          MaxEpRet |           0.287 |
# |          MinEpRet |           0.236 |
# |  AverageTestEpRet |           0.158 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.158 |
# |      MinTestEpRet |           0.158 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.53e+04 |
# |     AverageQ1Vals |          0.0903 |
# |         StdQ1Vals |         0.00271 |
# |         MaxQ1Vals |          0.0989 |
# |         MinQ1Vals |          0.0806 |
# |     AverageQ2Vals |          0.0903 |
# |         StdQ2Vals |        0.000694 |
# |         MaxQ2Vals |          0.0917 |
# |         MinQ2Vals |          0.0891 |
# |      AverageLogPi |           0.149 |
# |          StdLogPi |           0.953 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |           -7.06 |
# |            LossPi |         -0.0898 |
# |             LossQ |        0.000521 |
# |              Time |             205 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0562 |
# |           asset_1 |           0.944 |
# |             Epoch |             396 |
# |      AverageEpRet |           0.101 |
# |          StdEpRet |            0.22 |
# |          MaxEpRet |            0.32 |
# |          MinEpRet |          -0.119 |
# |  AverageTestEpRet |          0.0629 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |          0.0629 |
# |      MinTestEpRet |          0.0629 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.53e+04 |
# |     AverageQ1Vals |          0.0907 |
# |         StdQ1Vals |         0.00268 |
# |         MaxQ1Vals |           0.099 |
# |         MinQ1Vals |          0.0816 |
# |     AverageQ2Vals |          0.0907 |
# |         StdQ2Vals |        0.000945 |
# |         MaxQ2Vals |          0.0924 |
# |         MinQ2Vals |          0.0888 |
# |      AverageLogPi |           0.133 |
# |          StdLogPi |           0.972 |
# |          MaxLogPi |            1.11 |
# |          MinLogPi |            -7.7 |
# |            LossPi |         -0.0902 |
# |             LossQ |        0.000533 |
# |              Time |             205 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0553 |
# |           asset_1 |           0.945 |
# |             Epoch |             397 |
# |      AverageEpRet |           0.186 |
# |          StdEpRet |          0.0271 |
# |          MaxEpRet |           0.213 |
# |          MinEpRet |           0.159 |
# |  AverageTestEpRet |         -0.0584 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |         -0.0584 |
# |      MinTestEpRet |         -0.0584 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.54e+04 |
# |     AverageQ1Vals |          0.0908 |
# |         StdQ1Vals |         0.00281 |
# |         MaxQ1Vals |          0.0999 |
# |         MinQ1Vals |          0.0801 |
# |     AverageQ2Vals |          0.0908 |
# |         StdQ2Vals |          0.0012 |
# |         MaxQ2Vals |          0.0933 |
# |         MinQ2Vals |          0.0889 |
# |      AverageLogPi |           0.135 |
# |          StdLogPi |           0.963 |
# |          MaxLogPi |            1.12 |
# |          MinLogPi |           -6.63 |
# |            LossPi |         -0.0904 |
# |             LossQ |        0.000524 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0552 |
# |           asset_1 |           0.945 |
# |             Epoch |             398 |
# |      AverageEpRet |           0.252 |
# |          StdEpRet |           0.154 |
# |          MaxEpRet |           0.406 |
# |          MinEpRet |          0.0974 |
# |  AverageTestEpRet |           0.172 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.172 |
# |      MinTestEpRet |           0.172 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |          0.0906 |
# |         StdQ1Vals |         0.00273 |
# |         MaxQ1Vals |          0.0994 |
# |         MinQ1Vals |          0.0807 |
# |     AverageQ2Vals |          0.0905 |
# |         StdQ2Vals |         0.00103 |
# |         MaxQ2Vals |          0.0927 |
# |         MinQ2Vals |          0.0885 |
# |      AverageLogPi |           0.159 |
# |          StdLogPi |           0.943 |
# |          MaxLogPi |            1.12 |
# |          MinLogPi |           -7.76 |
# |            LossPi |         -0.0901 |
# |             LossQ |        0.000547 |
# |              Time |             206 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0554 |
# |           asset_1 |           0.945 |
# |             Epoch |             399 |
# |      AverageEpRet |          0.0853 |
# |          StdEpRet |           0.211 |
# |          MaxEpRet |           0.297 |
# |          MinEpRet |          -0.126 |
# |  AverageTestEpRet |           0.117 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.117 |
# |      MinTestEpRet |           0.117 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.55e+04 |
# |     AverageQ1Vals |          0.0913 |
# |         StdQ1Vals |         0.00259 |
# |         MaxQ1Vals |          0.0988 |
# |         MinQ1Vals |          0.0799 |
# |     AverageQ2Vals |          0.0913 |
# |         StdQ2Vals |         0.00065 |
# |         MaxQ2Vals |          0.0923 |
# |         MinQ2Vals |          0.0899 |
# |      AverageLogPi |           0.158 |
# |          StdLogPi |           0.936 |
# |          MaxLogPi |            1.12 |
# |          MinLogPi |           -7.16 |
# |            LossPi |         -0.0908 |
# |             LossQ |        0.000466 |
# |              Time |             207 |
# ---------------------------------------
# ---------------------------------------
# |           asset_0 |          0.0549 |
# |           asset_1 |           0.945 |
# |             Epoch |             400 |
# |      AverageEpRet |           0.213 |
# |          StdEpRet |           0.033 |
# |          MaxEpRet |           0.246 |
# |          MinEpRet |           0.181 |
# |  AverageTestEpRet |           0.237 |
# |      StdTestEpRet |               0 |
# |      MaxTestEpRet |           0.237 |
# |      MinTestEpRet |           0.237 |
# |             EpLen |              32 |
# |         TestEpLen |              32 |
# | TotalEnvInteracts |        2.56e+04 |
# |     AverageQ1Vals |          0.0913 |
# |         StdQ1Vals |         0.00256 |
# |         MaxQ1Vals |           0.099 |
# |         MinQ1Vals |          0.0813 |
# |     AverageQ2Vals |          0.0913 |
# |         StdQ2Vals |        0.000787 |
# |         MaxQ2Vals |          0.0928 |
# |         MinQ2Vals |          0.0902 |
# |      AverageLogPi |           0.129 |
# |          StdLogPi |               1 |
# |          MaxLogPi |            1.12 |
# |          MinLogPi |           -7.34 |
# |            LossPi |         -0.0907 |
# |             LossQ |        0.000519 |
# |              Time |             207 |
# ---------------------------------------
