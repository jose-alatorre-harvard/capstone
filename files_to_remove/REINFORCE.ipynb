# %% [markdown]
# # Implementation of REINFORCE Algorithm
#
# ## What we did in this milestone?
#
# We implemented the Policy Gradient algorithm REINFORCE.  To test the performance and efficacy we evaluated it using simulated data.
#
#
# Just as a reminder the REIN
#
# Next we will present the results and the challengs that we faced

# %% [markdown]
# ## Reinforce Deep Setup
#
# ### Loss Function
#
# $$
# L=-\sum_{k,t}Q_{k,t}log(\pi(s_{k,t},a_{k,t}))
# $$
#
# where
# $$
# Q_{k,t}=\sum_{i=0}\gamma^ir_i
# $$

# %% [markdown]
# ## Challenge: n-asset dimensional action space parametrization.
#
# Our action space is has dimension $n$ where $n$ correponds to the number of assets in our portfolio. To parametrize our policy we followed the standard solution in the univariate case; creation a Gaussian Policy
#
# ### Gaussian Policy
#
# $$
# \pi(a |s,\boldsymbol\theta):=\frac{1}{\sigma(s,\boldsymbol\theta)\sqrt{2\pi}}exp(-\frac{(a-\mu(s,\boldsymbol\theta))^2}{2\sigma(s,\boldsymbol\theta)^2})
# $$
#
# #### Linear Parametrization
#
# $$
# \theta:=[\boldsymbol{\theta_{\mu}},\boldsymbol{\theta_{\sigma}}]
# $$
#
# $$
# \mu(s,\boldsymbol\theta) :=\boldsymbol{\theta_{\mu}}^T \pmb{x}(s)
# $$
#
# $$
# \sigma(s,\boldsymbol\theta) :=exp(\boldsymbol{\theta_{\sigma}}^T \pmb{x}(s))
# $$
#
# #### Gradients
#
# $$
# \nabla ln\pi(a|s,\boldsymbol\theta_\mu)=\frac{1}{\sigma(s,\boldsymbol\theta)^2}(a-\mu(s,\boldsymbol\theta))\pmb{x}(s)
# $$
#
# $$
# \nabla ln\pi(a|s,\boldsymbol\theta_\sigma)=\left(\frac{(a-\mu(s,\boldsymbol\theta))^2}{\sigma(s,\boldsymbol\theta)^2} -1\right)\pmb{x}(s)
# $$

# %% [markdown]
# **The challenge with the multivariate case is that we will need to parametrize the coviariance matrix as well** While an increase of $n*n/2$ may not be that much. If we account for the interaction of asset features (specialy if we use lags) then the number of paramters grows multiplicative $n*n*features/2$
#
# **Solution:** We decided to  use uncorrelated parametrizations i.e. we set the covariance of each individual action in the policy to 0.
#
# Still we calculated the mighty gradients for the multivariate case.

# %% [markdown]
# ##  Multivariate Case
#
# We have a continuous multivariate case parametrized the following way:
#
# $$
# \pi(a|s,\theta)=\frac{exp\left(\frac{1}{2}(a-\mu(s,\Theta_\mu))^T\Sigma(s,\theta_\Sigma)^{-1}(a-\mu(s,\Theta_\mu))\right)}{\sqrt{(2\pi)^k|\Sigma(s,\theta_\Sigma)|}}
# $$
#
# Where
#
# $$
# \mu(s,\Theta_\mu)=\Theta f
# $$
#
# The parametrization of $\Sigma$ will be defined as
#
# $$
# \Sigma{i,j}=\sum_k^m \theta^{\sigma}_{i,j,k}f_k
# $$
#
# $f=[f_1,...,f_m]$ is the vector of $m$ features and $\Theta$ is a row matrix $\theta_i^T=[\theta_{i,1}...\theta_{i,n}]$ . Hence each of the individual means is a linear combination of the features.
#
#
# Therefore to calculuate the log gradient we need to use Matrix Calculus. first, we define
#
# $$
# u=\Theta f
# $$
#
# then we can rewrite
#
# $$
# ln(\pi(a|s,\theta))=\frac{1}{2}(a-u)^T\Sigma(s,\theta_\Sigma)^{-1}(a-u) -ln(\sqrt{(2\pi)^k|\Sigma(s,\theta_\Sigma)|})
# $$
#
# By queation  [137] from http://www.math.uwaterloo.ca/~hwolkowi//matrixcookbook.pdf
# $$
# \nabla ln(\pi(a|s,\theta_{i,k}^\mu))=Tr[\frac{\partial g(u)}{\partial u}^T \frac{\partial u}{\partial \theta_{i,k}^\mu }]
# $$
#
# And then by equation [86] http://www.math.uwaterloo.ca/~hwolkowi//matrixcookbook.pdf
#
# $$
# \nabla ln(\pi(a|s,\theta_{i,k}^\mu))=Tr[(\Sigma^{-1}(a-\Theta f))^T I[i]*f_k]
# $$
#
# Where $I[i]$ is a row vector  with zeros in all rows and 1 in row $i$ This can expressed as
#
# $$
# \nabla ln(\pi(a|s,\theta_{i,k}^\mu))=\text{row}_i[\Sigma^{-1}(a-\Theta f)] * f_k
# $$

# %% [markdown]
# For the case of  $\Sigma$ we can also follow https://stats.stackexchange.com/questions/27436/how-to-take-derivative-of-multivariate-normal-density and apply the chain rule to obtain
#
# $$
# \nabla ln(\pi(a|s,\theta_{i,j,k}^\sigma))=Tr\left[[-\frac{1}{2}(\Sigma^{-1}-\Sigma^{-1}(a-\mu(s,\Theta_\mu))(a-\mu(s,\Theta_\mu))^T \Sigma^{-1}]^T I[i=i,j=j]*f_k\right]
# $$

# %% [markdown]
# ## Evaluations
#
# To evaluate the algorithm we  tried three different rewards functions:
#
# * Maximum return : The Agent receives a reward on each step equals to the return of the portfolio on 1-step
# * Maximum Sharpe: The Agent receives 0 as reward on each steap until the end of an episode when the agent receives the Sharpe ratio.
# * Monimum volatility : The Agent receives 0 as reward on each step until the  end of an episode when the agent receives the negative of the volatility of the portfolio.
#
# Important to mention that at each step the Agent observes the state that equals the previous weights in the portfolio and the last 32 log returns of each asset.
#
# Below we will present the case of minimum volatility as an example. The results where pretty similar for other  reward functions

# %%
from lib.Environment_refactored import DeepTradingEnvironment, LinearAgent
import datetime
import numpy as np
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.plotting import plot_efficient_frontier
from pypfopt.cla import CLA

out_reward_window=datetime.timedelta(days=7)
# parameters related to the transformation of data, this parameters govern an step before the algorithm
meta_parameters = {"in_bars_count": 30,
                   "out_reward_window":out_reward_window ,
                   "state_type":"in_window_out_window"}

# parameters that are related to the objective/reward function construction
objective_parameters = {"percent_commission": .001,
                        }
print("===Meta Parameters===")
print(meta_parameters)
print("===Objective Parameters===")
print(objective_parameters)


assets_simulation_details={"asset_1":{"method":"GBM","sigma":.01,"mean":.02},
                    "asset_2":{"method":"GBM","sigma":.03,"mean":.18}}

env=DeepTradingEnvironment.build_environment_from_simulated_assets(assets_simulation_details=assets_simulation_details,
                                                                     data_hash="simulation_gbm",
                                                                     meta_parameters=meta_parameters,
                                                                     objective_parameters=objective_parameters)
cov=np.array([[assets_simulation_details["asset_1"]["sigma"]**2,0],[0,assets_simulation_details["asset_2"]["sigma"]**2]])
mus=np.array([assets_simulation_details["asset_1"]["mean"],assets_simulation_details["asset_2"]["mean"]])

ef = EfficientFrontier(mus, cov)
# weights = ef.max_sharpe(risk_free_rate=0)
weights = ef.min_volatility()
print("minum volatility weights",weights)
# Out:
# ===Meta Parameters===
# {'in_bars_count': 30, 'out_reward_window': datetime.timedelta(days=7), 'state_type': 'in_window_out_window'}
# ===Objective Parameters===
# {'percent_commission': 0.001}
# minum volatility weights OrderedDict([(0, 0.8999999999996016), (1, 0.1000000000003984)])

# %%
x=np.array(list(weights.values())).reshape(-1,1)
p_vol=np.sqrt(np.matmul(np.matmul(x.T,cov),x))
p_sharpe=np.matmul(x.T,mus)/p_vol
linear_agent=LinearAgent(environment=env,out_reward_window_td=out_reward_window,
                         reward_function="cum_return",sample_observations=32)
linear_agent.set_plot_weights(weights=np.array(list(weights.values())),
                              benchmark_G=-p_vol.ravel()[0])
# Out:
# pre-sampling indices: 100%|██████████| 1373/1373 [00:16<00:00, 84.11it/s]

# %%
# linear_agent.REINFORCE_fit()
linear_agent.REINFORCE_fit(add_baseline=False)
# Out:
#   2%|▏         | 200/10000 [00:17<14:04, 11.61it/s]
#   4%|▍         | 400/10000 [00:34<13:56, 11.48it/s]
#   6%|▌         | 600/10000 [00:51<13:48, 11.35it/s]
#   8%|▊         | 800/10000 [01:08<12:56, 11.85it/s]
#  10%|█         | 1000/10000 [01:26<12:48, 11.71it/s]
#  12%|█▏        | 1199/10000 [01:43<12:35, 11.65it/s]
#  14%|█▍        | 1399/10000 [02:01<12:16, 11.67it/s]
#  16%|█▌        | 1599/10000 [02:18<11:55, 11.74it/s]
#  18%|█▊        | 1799/10000 [02:36<11:36, 11.78it/s]
#  20%|█▉        | 1999/10000 [02:53<11:42, 11.39it/s]
#  22%|██▏       | 2199/10000 [03:11<11:24, 11.40it/s]
#  24%|██▍       | 2399/10000 [03:28<10:47, 11.73it/s]
#  26%|██▌       | 2599/10000 [03:46<10:29, 11.76it/s]
#  28%|██▊       | 2799/10000 [04:04<10:09, 11.82it/s]
#  30%|███       | 3000/10000 [04:21<09:49, 11.87it/s]
#  32%|███▏      | 3200/10000 [04:38<09:51, 11.49it/s]
#  34%|███▍      | 3400/10000 [04:56<09:31, 11.55it/s]
#  36%|███▌      | 3600/10000 [05:13<09:34, 11.13it/s]
#  38%|███▊      | 3799/10000 [05:31<08:56, 11.56it/s]
#  40%|████      | 4000/10000 [05:48<08:30, 11.76it/s]
#  42%|████▏     | 4200/10000 [06:06<08:10, 11.83it/s]
#  44%|████▍     | 4400/10000 [06:23<07:49, 11.94it/s]
#  46%|████▌     | 4600/10000 [06:41<07:42, 11.68it/s]
#  48%|████▊     | 4800/10000 [06:58<07:27, 11.61it/s]
#  50%|█████     | 5000/10000 [07:16<07:14, 11.52it/s]
#  52%|█████▏    | 5200/10000 [07:34<06:49, 11.72it/s]
#  54%|█████▍    | 5400/10000 [07:51<06:26, 11.89it/s]
#  56%|█████▌    | 5600/10000 [08:09<06:10, 11.88it/s]
#  58%|█████▊    | 5800/10000 [08:26<05:58, 11.71it/s]
#  60%|██████    | 6000/10000 [08:44<05:50, 11.42it/s]
#  62%|██████▏   | 6200/10000 [09:01<05:19, 11.89it/s]
#  64%|██████▍   | 6400/10000 [09:19<05:02, 11.89it/s]
#  66%|██████▌   | 6600/10000 [09:37<04:49, 11.74it/s]
#  68%|██████▊   | 6800/10000 [09:54<04:34, 11.64it/s]
#  70%|███████   | 7000/10000 [10:12<04:15, 11.72it/s]
#  72%|███████▏  | 7199/10000 [10:30<03:57, 11.79it/s]
#  74%|███████▍  | 7399/10000 [10:47<03:45, 11.54it/s]
#  76%|███████▌  | 7599/10000 [11:05<03:24, 11.74it/s]
#  78%|███████▊  | 7799/10000 [11:22<03:07, 11.72it/s]
#  80%|███████▉  | 7999/10000 [11:40<02:50, 11.74it/s]
#  82%|████████▏ | 8199/10000 [11:57<02:35, 11.56it/s]
#  84%|████████▍ | 8399/10000 [12:15<02:16, 11.73it/s]
#  86%|████████▌ | 8599/10000 [12:33<02:07, 10.99it/s]
#  88%|████████▊ | 8799/10000 [12:50<01:42, 11.71it/s]
#  90%|█████████ | 9000/10000 [13:08<01:24, 11.78it/s]
#  92%|█████████▏| 9200/10000 [13:26<01:07, 11.86it/s]
#  94%|█████████▍| 9399/10000 [13:43<00:51, 11.66it/s]
#  96%|█████████▌| 9599/10000 [14:01<00:34, 11.77it/s]
#  98%|█████████▊| 9799/10000 [14:18<00:17, 11.77it/s]
# 100%|█████████▉| 9999/10000 [14:36<00:00, 11.76it/s]
# [asset_1_forward_return_7_days,_0:00:00    0.513042
#  asset_2_forward_return_7_days,_0:00:00    0.494864
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517657
#  asset_2_forward_return_7_days,_0:00:00    0.488793
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.515162
#  asset_2_forward_return_7_days,_0:00:00    0.485435
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517700
#  asset_2_forward_return_7_days,_0:00:00    0.483025
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.528711
#  asset_2_forward_return_7_days,_0:00:00    0.479656
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533708
#  asset_2_forward_return_7_days,_0:00:00    0.475097
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542142
#  asset_2_forward_return_7_days,_0:00:00    0.475676
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.550489
#  asset_2_forward_return_7_days,_0:00:00    0.469514
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544535
#  asset_2_forward_return_7_days,_0:00:00    0.466614
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546994
#  asset_2_forward_return_7_days,_0:00:00    0.458599
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539521
#  asset_2_forward_return_7_days,_0:00:00    0.459979
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546377
#  asset_2_forward_return_7_days,_0:00:00    0.460433
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544424
#  asset_2_forward_return_7_days,_0:00:00    0.457943
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548257
#  asset_2_forward_return_7_days,_0:00:00    0.455294
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552875
#  asset_2_forward_return_7_days,_0:00:00    0.450309
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549084
#  asset_2_forward_return_7_days,_0:00:00    0.449629
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.545690
#  asset_2_forward_return_7_days,_0:00:00    0.444711
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553174
#  asset_2_forward_return_7_days,_0:00:00    0.446260
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.560080
#  asset_2_forward_return_7_days,_0:00:00    0.464475
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.557767
#  asset_2_forward_return_7_days,_0:00:00    0.480602
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548310
#  asset_2_forward_return_7_days,_0:00:00    0.467026
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544887
#  asset_2_forward_return_7_days,_0:00:00    0.473248
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.537283
#  asset_2_forward_return_7_days,_0:00:00    0.476746
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535339
#  asset_2_forward_return_7_days,_0:00:00    0.478881
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.537218
#  asset_2_forward_return_7_days,_0:00:00    0.475724
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521535
#  asset_2_forward_return_7_days,_0:00:00    0.477850
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522159
#  asset_2_forward_return_7_days,_0:00:00    0.467082
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.531637
#  asset_2_forward_return_7_days,_0:00:00    0.461882
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520147
#  asset_2_forward_return_7_days,_0:00:00    0.458178
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.510811
#  asset_2_forward_return_7_days,_0:00:00    0.459655
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514825
#  asset_2_forward_return_7_days,_0:00:00    0.458937
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521287
#  asset_2_forward_return_7_days,_0:00:00    0.466449
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.530262
#  asset_2_forward_return_7_days,_0:00:00    0.464418
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538380
#  asset_2_forward_return_7_days,_0:00:00    0.466096
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535092
#  asset_2_forward_return_7_days,_0:00:00    0.453692
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.528232
#  asset_2_forward_return_7_days,_0:00:00    0.446806
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536150
#  asset_2_forward_return_7_days,_0:00:00    0.460739
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533186
#  asset_2_forward_return_7_days,_0:00:00    0.464782
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.530767
#  asset_2_forward_return_7_days,_0:00:00    0.448985
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.526398
#  asset_2_forward_return_7_days,_0:00:00    0.452057
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.525003
#  asset_2_forward_return_7_days,_0:00:00    0.446547
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521866
#  asset_2_forward_return_7_days,_0:00:00    0.453965
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.525144
#  asset_2_forward_return_7_days,_0:00:00    0.460090
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514454
#  asset_2_forward_return_7_days,_0:00:00    0.470707
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.515152
#  asset_2_forward_return_7_days,_0:00:00    0.461340
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.515412
#  asset_2_forward_return_7_days,_0:00:00    0.466617
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520947
#  asset_2_forward_return_7_days,_0:00:00    0.457639
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516383
#  asset_2_forward_return_7_days,_0:00:00    0.458288
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.512053
#  asset_2_forward_return_7_days,_0:00:00    0.470501
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.512175
#  asset_2_forward_return_7_days,_0:00:00    0.469189
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516702
#  asset_2_forward_return_7_days,_0:00:00    0.466925
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518360
#  asset_2_forward_return_7_days,_0:00:00    0.468681
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517503
#  asset_2_forward_return_7_days,_0:00:00    0.484384
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.513412
#  asset_2_forward_return_7_days,_0:00:00    0.464024
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516131
#  asset_2_forward_return_7_days,_0:00:00    0.475560
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522740
#  asset_2_forward_return_7_days,_0:00:00    0.484348
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521119
#  asset_2_forward_return_7_days,_0:00:00    0.487072
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529840
#  asset_2_forward_return_7_days,_0:00:00    0.495164
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.526456
#  asset_2_forward_return_7_days,_0:00:00    0.485064
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.525579
#  asset_2_forward_return_7_days,_0:00:00    0.481993
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.509455
#  asset_2_forward_return_7_days,_0:00:00    0.482616
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.509884
#  asset_2_forward_return_7_days,_0:00:00    0.477075
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517470
#  asset_2_forward_return_7_days,_0:00:00    0.475233
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.500201
#  asset_2_forward_return_7_days,_0:00:00    0.469397
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.497841
#  asset_2_forward_return_7_days,_0:00:00    0.466904
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.499203
#  asset_2_forward_return_7_days,_0:00:00    0.461211
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514843
#  asset_2_forward_return_7_days,_0:00:00    0.468497
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518883
#  asset_2_forward_return_7_days,_0:00:00    0.489617
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518819
#  asset_2_forward_return_7_days,_0:00:00    0.484758
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517231
#  asset_2_forward_return_7_days,_0:00:00    0.483525
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.512732
#  asset_2_forward_return_7_days,_0:00:00    0.475516
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520208
#  asset_2_forward_return_7_days,_0:00:00    0.478183
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518038
#  asset_2_forward_return_7_days,_0:00:00    0.477707
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516946
#  asset_2_forward_return_7_days,_0:00:00    0.482057
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520025
#  asset_2_forward_return_7_days,_0:00:00    0.484522
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522659
#  asset_2_forward_return_7_days,_0:00:00    0.470809
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523522
#  asset_2_forward_return_7_days,_0:00:00    0.489099
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522792
#  asset_2_forward_return_7_days,_0:00:00    0.483355
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.524672
#  asset_2_forward_return_7_days,_0:00:00    0.483112
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.525163
#  asset_2_forward_return_7_days,_0:00:00    0.473739
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532391
#  asset_2_forward_return_7_days,_0:00:00    0.466738
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.531660
#  asset_2_forward_return_7_days,_0:00:00    0.474388
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542114
#  asset_2_forward_return_7_days,_0:00:00    0.481278
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541423
#  asset_2_forward_return_7_days,_0:00:00    0.471915
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540927
#  asset_2_forward_return_7_days,_0:00:00    0.471361
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534772
#  asset_2_forward_return_7_days,_0:00:00    0.479835
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536035
#  asset_2_forward_return_7_days,_0:00:00    0.486026
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.52719
#  asset_2_forward_return_7_days,_0:00:00    0.49216
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523704
#  asset_2_forward_return_7_days,_0:00:00    0.494372
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522878
#  asset_2_forward_return_7_days,_0:00:00    0.485576
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517823
#  asset_2_forward_return_7_days,_0:00:00    0.484661
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.526868
#  asset_2_forward_return_7_days,_0:00:00    0.484228
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534485
#  asset_2_forward_return_7_days,_0:00:00    0.483350
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.531974
#  asset_2_forward_return_7_days,_0:00:00    0.481575
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533587
#  asset_2_forward_return_7_days,_0:00:00    0.480651
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529060
#  asset_2_forward_return_7_days,_0:00:00    0.485584
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523305
#  asset_2_forward_return_7_days,_0:00:00    0.481277
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.513769
#  asset_2_forward_return_7_days,_0:00:00    0.487332
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514607
#  asset_2_forward_return_7_days,_0:00:00    0.486132
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518576
#  asset_2_forward_return_7_days,_0:00:00    0.484879
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.525428
#  asset_2_forward_return_7_days,_0:00:00    0.487565
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.527707
#  asset_2_forward_return_7_days,_0:00:00    0.484202
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.524253
#  asset_2_forward_return_7_days,_0:00:00    0.479903
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.519300
#  asset_2_forward_return_7_days,_0:00:00    0.484665
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521087
#  asset_2_forward_return_7_days,_0:00:00    0.489753
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.530065
#  asset_2_forward_return_7_days,_0:00:00    0.491526
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529981
#  asset_2_forward_return_7_days,_0:00:00    0.496619
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522636
#  asset_2_forward_return_7_days,_0:00:00    0.496284
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.509392
#  asset_2_forward_return_7_days,_0:00:00    0.492707
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.512920
#  asset_2_forward_return_7_days,_0:00:00    0.492202
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.510754
#  asset_2_forward_return_7_days,_0:00:00    0.491158
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.505332
#  asset_2_forward_return_7_days,_0:00:00    0.497532
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.501412
#  asset_2_forward_return_7_days,_0:00:00    0.507633
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.501574
#  asset_2_forward_return_7_days,_0:00:00    0.517281
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.500911
#  asset_2_forward_return_7_days,_0:00:00    0.512627
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.500888
#  asset_2_forward_return_7_days,_0:00:00    0.499682
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.500023
#  asset_2_forward_return_7_days,_0:00:00    0.497960
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.505573
#  asset_2_forward_return_7_days,_0:00:00    0.503237
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.504094
#  asset_2_forward_return_7_days,_0:00:00    0.498121
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.509053
#  asset_2_forward_return_7_days,_0:00:00    0.489415
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516302
#  asset_2_forward_return_7_days,_0:00:00    0.479929
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.509323
#  asset_2_forward_return_7_days,_0:00:00    0.481689
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.508585
#  asset_2_forward_return_7_days,_0:00:00    0.482862
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.508409
#  asset_2_forward_return_7_days,_0:00:00    0.497863
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.502472
#  asset_2_forward_return_7_days,_0:00:00    0.501191
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.500957
#  asset_2_forward_return_7_days,_0:00:00    0.505123
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.511569
#  asset_2_forward_return_7_days,_0:00:00    0.507035
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514373
#  asset_2_forward_return_7_days,_0:00:00    0.511727
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.503160
#  asset_2_forward_return_7_days,_0:00:00    0.504322
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.509698
#  asset_2_forward_return_7_days,_0:00:00    0.485341
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.504148
#  asset_2_forward_return_7_days,_0:00:00    0.491500
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.505535
#  asset_2_forward_return_7_days,_0:00:00    0.493974
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.503090
#  asset_2_forward_return_7_days,_0:00:00    0.500389
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.498919
#  asset_2_forward_return_7_days,_0:00:00    0.516850
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.488361
#  asset_2_forward_return_7_days,_0:00:00    0.506784
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.481600
#  asset_2_forward_return_7_days,_0:00:00    0.503528
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.495656
#  asset_2_forward_return_7_days,_0:00:00    0.509301
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.482132
#  asset_2_forward_return_7_days,_0:00:00    0.514005
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.483718
#  asset_2_forward_return_7_days,_0:00:00    0.503218
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.488358
#  asset_2_forward_return_7_days,_0:00:00    0.482654
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.498288
#  asset_2_forward_return_7_days,_0:00:00    0.486381
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.500390
#  asset_2_forward_return_7_days,_0:00:00    0.485052
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.481675
#  asset_2_forward_return_7_days,_0:00:00    0.487668
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.493943
#  asset_2_forward_return_7_days,_0:00:00    0.490692
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.494506
#  asset_2_forward_return_7_days,_0:00:00    0.494666
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.503344
#  asset_2_forward_return_7_days,_0:00:00    0.494865
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.501591
#  asset_2_forward_return_7_days,_0:00:00    0.498297
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.504631
#  asset_2_forward_return_7_days,_0:00:00    0.494355
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.512149
#  asset_2_forward_return_7_days,_0:00:00    0.499946
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.510194
#  asset_2_forward_return_7_days,_0:00:00    0.496571
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514026
#  asset_2_forward_return_7_days,_0:00:00    0.495049
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514354
#  asset_2_forward_return_7_days,_0:00:00    0.495079
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.513161
#  asset_2_forward_return_7_days,_0:00:00    0.494626
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514610
#  asset_2_forward_return_7_days,_0:00:00    0.497672
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514382
#  asset_2_forward_return_7_days,_0:00:00    0.495883
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.511853
#  asset_2_forward_return_7_days,_0:00:00    0.494189
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.512781
#  asset_2_forward_return_7_days,_0:00:00    0.489944
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.513999
#  asset_2_forward_return_7_days,_0:00:00    0.487028
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521455
#  asset_2_forward_return_7_days,_0:00:00    0.485862
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.524651
#  asset_2_forward_return_7_days,_0:00:00    0.481211
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.510673
#  asset_2_forward_return_7_days,_0:00:00    0.489359
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522577
#  asset_2_forward_return_7_days,_0:00:00    0.477010
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523503
#  asset_2_forward_return_7_days,_0:00:00    0.476826
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518902
#  asset_2_forward_return_7_days,_0:00:00    0.482351
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514382
#  asset_2_forward_return_7_days,_0:00:00    0.481494
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.509732
#  asset_2_forward_return_7_days,_0:00:00    0.482757
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521157
#  asset_2_forward_return_7_days,_0:00:00    0.477716
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523670
#  asset_2_forward_return_7_days,_0:00:00    0.476595
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516177
#  asset_2_forward_return_7_days,_0:00:00    0.468482
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.510456
#  asset_2_forward_return_7_days,_0:00:00    0.467672
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514902
#  asset_2_forward_return_7_days,_0:00:00    0.461411
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516456
#  asset_2_forward_return_7_days,_0:00:00    0.458511
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529029
#  asset_2_forward_return_7_days,_0:00:00    0.459393
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520574
#  asset_2_forward_return_7_days,_0:00:00    0.452773
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529636
#  asset_2_forward_return_7_days,_0:00:00    0.458458
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523165
#  asset_2_forward_return_7_days,_0:00:00    0.459371
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533454
#  asset_2_forward_return_7_days,_0:00:00    0.463146
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540244
#  asset_2_forward_return_7_days,_0:00:00    0.445160
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543708
#  asset_2_forward_return_7_days,_0:00:00    0.445292
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536702
#  asset_2_forward_return_7_days,_0:00:00    0.449447
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541149
#  asset_2_forward_return_7_days,_0:00:00    0.450950
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546529
#  asset_2_forward_return_7_days,_0:00:00    0.457527
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539816
#  asset_2_forward_return_7_days,_0:00:00    0.452024
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529964
#  asset_2_forward_return_7_days,_0:00:00    0.451564
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533301
#  asset_2_forward_return_7_days,_0:00:00    0.458775
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.537422
#  asset_2_forward_return_7_days,_0:00:00    0.466145
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535265
#  asset_2_forward_return_7_days,_0:00:00    0.472609
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535196
#  asset_2_forward_return_7_days,_0:00:00    0.466610
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534952
#  asset_2_forward_return_7_days,_0:00:00    0.467385
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.527458
#  asset_2_forward_return_7_days,_0:00:00    0.462420
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535682
#  asset_2_forward_return_7_days,_0:00:00    0.461441
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.528687
#  asset_2_forward_return_7_days,_0:00:00    0.449853
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534563
#  asset_2_forward_return_7_days,_0:00:00    0.451042
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552455
#  asset_2_forward_return_7_days,_0:00:00    0.461516
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544282
#  asset_2_forward_return_7_days,_0:00:00    0.467727
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544019
#  asset_2_forward_return_7_days,_0:00:00    0.467793
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536368
#  asset_2_forward_return_7_days,_0:00:00    0.475287
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539142
#  asset_2_forward_return_7_days,_0:00:00    0.476258
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532924
#  asset_2_forward_return_7_days,_0:00:00    0.474574
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.526120
#  asset_2_forward_return_7_days,_0:00:00    0.481939
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538252
#  asset_2_forward_return_7_days,_0:00:00    0.470406
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544504
#  asset_2_forward_return_7_days,_0:00:00    0.467446
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544391
#  asset_2_forward_return_7_days,_0:00:00    0.466143
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544839
#  asset_2_forward_return_7_days,_0:00:00    0.471451
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549872
#  asset_2_forward_return_7_days,_0:00:00    0.470557
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539667
#  asset_2_forward_return_7_days,_0:00:00    0.476975
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.530144
#  asset_2_forward_return_7_days,_0:00:00    0.483228
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523971
#  asset_2_forward_return_7_days,_0:00:00    0.480637
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540751
#  asset_2_forward_return_7_days,_0:00:00    0.487936
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548423
#  asset_2_forward_return_7_days,_0:00:00    0.499276
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538738
#  asset_2_forward_return_7_days,_0:00:00    0.496905
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.537804
#  asset_2_forward_return_7_days,_0:00:00    0.492237
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535080
#  asset_2_forward_return_7_days,_0:00:00    0.498132
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542187
#  asset_2_forward_return_7_days,_0:00:00    0.492739
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538902
#  asset_2_forward_return_7_days,_0:00:00    0.495628
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533728
#  asset_2_forward_return_7_days,_0:00:00    0.499519
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532367
#  asset_2_forward_return_7_days,_0:00:00    0.491804
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538502
#  asset_2_forward_return_7_days,_0:00:00    0.491900
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.545928
#  asset_2_forward_return_7_days,_0:00:00    0.487295
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547513
#  asset_2_forward_return_7_days,_0:00:00    0.486131
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542600
#  asset_2_forward_return_7_days,_0:00:00    0.456011
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543361
#  asset_2_forward_return_7_days,_0:00:00    0.458880
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543426
#  asset_2_forward_return_7_days,_0:00:00    0.454211
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552313
#  asset_2_forward_return_7_days,_0:00:00    0.457485
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542086
#  asset_2_forward_return_7_days,_0:00:00    0.458145
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549401
#  asset_2_forward_return_7_days,_0:00:00    0.452040
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539927
#  asset_2_forward_return_7_days,_0:00:00    0.473429
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544199
#  asset_2_forward_return_7_days,_0:00:00    0.460831
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533066
#  asset_2_forward_return_7_days,_0:00:00    0.463275
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533727
#  asset_2_forward_return_7_days,_0:00:00    0.476501
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532811
#  asset_2_forward_return_7_days,_0:00:00    0.477902
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523504
#  asset_2_forward_return_7_days,_0:00:00    0.481708
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.515027
#  asset_2_forward_return_7_days,_0:00:00    0.481387
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516505
#  asset_2_forward_return_7_days,_0:00:00    0.475943
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.508994
#  asset_2_forward_return_7_days,_0:00:00    0.481694
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.500758
#  asset_2_forward_return_7_days,_0:00:00    0.483178
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.502211
#  asset_2_forward_return_7_days,_0:00:00    0.489490
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516365
#  asset_2_forward_return_7_days,_0:00:00    0.485528
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.507322
#  asset_2_forward_return_7_days,_0:00:00    0.487438
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.511217
#  asset_2_forward_return_7_days,_0:00:00    0.479933
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.508945
#  asset_2_forward_return_7_days,_0:00:00    0.479587
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.510537
#  asset_2_forward_return_7_days,_0:00:00    0.471853
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.515067
#  asset_2_forward_return_7_days,_0:00:00    0.470464
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518126
#  asset_2_forward_return_7_days,_0:00:00    0.460447
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532151
#  asset_2_forward_return_7_days,_0:00:00    0.447814
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536539
#  asset_2_forward_return_7_days,_0:00:00    0.442719
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538966
#  asset_2_forward_return_7_days,_0:00:00    0.461488
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539819
#  asset_2_forward_return_7_days,_0:00:00    0.469371
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544717
#  asset_2_forward_return_7_days,_0:00:00    0.476320
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543114
#  asset_2_forward_return_7_days,_0:00:00    0.469915
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543397
#  asset_2_forward_return_7_days,_0:00:00    0.465765
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548655
#  asset_2_forward_return_7_days,_0:00:00    0.468735
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.550231
#  asset_2_forward_return_7_days,_0:00:00    0.476359
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.566737
#  asset_2_forward_return_7_days,_0:00:00    0.467168
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.56803
#  asset_2_forward_return_7_days,_0:00:00    0.47501
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.565881
#  asset_2_forward_return_7_days,_0:00:00    0.478454
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.564980
#  asset_2_forward_return_7_days,_0:00:00    0.490834
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.558199
#  asset_2_forward_return_7_days,_0:00:00    0.483388
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552079
#  asset_2_forward_return_7_days,_0:00:00    0.483682
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548891
#  asset_2_forward_return_7_days,_0:00:00    0.470184
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549919
#  asset_2_forward_return_7_days,_0:00:00    0.468897
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553887
#  asset_2_forward_return_7_days,_0:00:00    0.459565
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.545257
#  asset_2_forward_return_7_days,_0:00:00    0.467022
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543248
#  asset_2_forward_return_7_days,_0:00:00    0.462023
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541013
#  asset_2_forward_return_7_days,_0:00:00    0.467202
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535947
#  asset_2_forward_return_7_days,_0:00:00    0.472832
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.527290
#  asset_2_forward_return_7_days,_0:00:00    0.474317
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.524574
#  asset_2_forward_return_7_days,_0:00:00    0.476490
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.527498
#  asset_2_forward_return_7_days,_0:00:00    0.480211
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.527503
#  asset_2_forward_return_7_days,_0:00:00    0.482637
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521861
#  asset_2_forward_return_7_days,_0:00:00    0.476246
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522653
#  asset_2_forward_return_7_days,_0:00:00    0.476916
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521025
#  asset_2_forward_return_7_days,_0:00:00    0.478187
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520421
#  asset_2_forward_return_7_days,_0:00:00    0.480685
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522556
#  asset_2_forward_return_7_days,_0:00:00    0.473648
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521577
#  asset_2_forward_return_7_days,_0:00:00    0.467013
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521866
#  asset_2_forward_return_7_days,_0:00:00    0.465640
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523769
#  asset_2_forward_return_7_days,_0:00:00    0.465109
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517034
#  asset_2_forward_return_7_days,_0:00:00    0.481691
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533688
#  asset_2_forward_return_7_days,_0:00:00    0.469138
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.527470
#  asset_2_forward_return_7_days,_0:00:00    0.470376
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521754
#  asset_2_forward_return_7_days,_0:00:00    0.448283
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.516844
#  asset_2_forward_return_7_days,_0:00:00    0.452487
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522262
#  asset_2_forward_return_7_days,_0:00:00    0.461368
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.508340
#  asset_2_forward_return_7_days,_0:00:00    0.459921
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.514745
#  asset_2_forward_return_7_days,_0:00:00    0.461601
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518619
#  asset_2_forward_return_7_days,_0:00:00    0.460094
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529221
#  asset_2_forward_return_7_days,_0:00:00    0.453303
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534540
#  asset_2_forward_return_7_days,_0:00:00    0.448899
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536647
#  asset_2_forward_return_7_days,_0:00:00    0.443441
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540037
#  asset_2_forward_return_7_days,_0:00:00    0.457502
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547804
#  asset_2_forward_return_7_days,_0:00:00    0.458005
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547858
#  asset_2_forward_return_7_days,_0:00:00    0.465869
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.54938
#  asset_2_forward_return_7_days,_0:00:00    0.47052
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552766
#  asset_2_forward_return_7_days,_0:00:00    0.464004
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.556589
#  asset_2_forward_return_7_days,_0:00:00    0.461163
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.545122
#  asset_2_forward_return_7_days,_0:00:00    0.456975
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.554895
#  asset_2_forward_return_7_days,_0:00:00    0.446081
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540647
#  asset_2_forward_return_7_days,_0:00:00    0.455896
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532726
#  asset_2_forward_return_7_days,_0:00:00    0.468202
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538668
#  asset_2_forward_return_7_days,_0:00:00    0.474692
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549112
#  asset_2_forward_return_7_days,_0:00:00    0.483695
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544630
#  asset_2_forward_return_7_days,_0:00:00    0.474388
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548207
#  asset_2_forward_return_7_days,_0:00:00    0.474753
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.545943
#  asset_2_forward_return_7_days,_0:00:00    0.474921
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544958
#  asset_2_forward_return_7_days,_0:00:00    0.471777
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542346
#  asset_2_forward_return_7_days,_0:00:00    0.465247
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543463
#  asset_2_forward_return_7_days,_0:00:00    0.454763
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.550587
#  asset_2_forward_return_7_days,_0:00:00    0.461826
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.550179
#  asset_2_forward_return_7_days,_0:00:00    0.459579
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.561070
#  asset_2_forward_return_7_days,_0:00:00    0.455681
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.560695
#  asset_2_forward_return_7_days,_0:00:00    0.445356
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.557834
#  asset_2_forward_return_7_days,_0:00:00    0.439227
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.562543
#  asset_2_forward_return_7_days,_0:00:00    0.445290
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.564323
#  asset_2_forward_return_7_days,_0:00:00    0.439529
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.562820
#  asset_2_forward_return_7_days,_0:00:00    0.453928
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552881
#  asset_2_forward_return_7_days,_0:00:00    0.448456
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543133
#  asset_2_forward_return_7_days,_0:00:00    0.454908
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552430
#  asset_2_forward_return_7_days,_0:00:00    0.465742
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552195
#  asset_2_forward_return_7_days,_0:00:00    0.472209
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.564427
#  asset_2_forward_return_7_days,_0:00:00    0.470482
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.551314
#  asset_2_forward_return_7_days,_0:00:00    0.467789
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.551779
#  asset_2_forward_return_7_days,_0:00:00    0.473416
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541032
#  asset_2_forward_return_7_days,_0:00:00    0.476581
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.554175
#  asset_2_forward_return_7_days,_0:00:00    0.472623
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.563426
#  asset_2_forward_return_7_days,_0:00:00    0.454621
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552524
#  asset_2_forward_return_7_days,_0:00:00    0.458357
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549507
#  asset_2_forward_return_7_days,_0:00:00    0.457938
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548745
#  asset_2_forward_return_7_days,_0:00:00    0.453207
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.565015
#  asset_2_forward_return_7_days,_0:00:00    0.444076
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.561020
#  asset_2_forward_return_7_days,_0:00:00    0.452549
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547432
#  asset_2_forward_return_7_days,_0:00:00    0.453483
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549704
#  asset_2_forward_return_7_days,_0:00:00    0.475223
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.555291
#  asset_2_forward_return_7_days,_0:00:00    0.481738
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.561379
#  asset_2_forward_return_7_days,_0:00:00    0.471102
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.555963
#  asset_2_forward_return_7_days,_0:00:00    0.489675
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549288
#  asset_2_forward_return_7_days,_0:00:00    0.475869
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532330
#  asset_2_forward_return_7_days,_0:00:00    0.471905
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.531879
#  asset_2_forward_return_7_days,_0:00:00    0.466717
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547077
#  asset_2_forward_return_7_days,_0:00:00    0.464310
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.531544
#  asset_2_forward_return_7_days,_0:00:00    0.459584
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.530469
#  asset_2_forward_return_7_days,_0:00:00    0.461067
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.524729
#  asset_2_forward_return_7_days,_0:00:00    0.456349
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520714
#  asset_2_forward_return_7_days,_0:00:00    0.456467
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.517100
#  asset_2_forward_return_7_days,_0:00:00    0.459434
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.515124
#  asset_2_forward_return_7_days,_0:00:00    0.447053
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529264
#  asset_2_forward_return_7_days,_0:00:00    0.448153
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532776
#  asset_2_forward_return_7_days,_0:00:00    0.454231
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.537337
#  asset_2_forward_return_7_days,_0:00:00    0.453185
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546059
#  asset_2_forward_return_7_days,_0:00:00    0.456177
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.54257
#  asset_2_forward_return_7_days,_0:00:00    0.45687
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.53426
#  asset_2_forward_return_7_days,_0:00:00    0.45806
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534347
#  asset_2_forward_return_7_days,_0:00:00    0.455074
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534031
#  asset_2_forward_return_7_days,_0:00:00    0.462809
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539597
#  asset_2_forward_return_7_days,_0:00:00    0.457082
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536953
#  asset_2_forward_return_7_days,_0:00:00    0.454407
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.526982
#  asset_2_forward_return_7_days,_0:00:00    0.456734
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.537395
#  asset_2_forward_return_7_days,_0:00:00    0.459837
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535921
#  asset_2_forward_return_7_days,_0:00:00    0.466126
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.526324
#  asset_2_forward_return_7_days,_0:00:00    0.457977
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534792
#  asset_2_forward_return_7_days,_0:00:00    0.470450
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538142
#  asset_2_forward_return_7_days,_0:00:00    0.455811
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539783
#  asset_2_forward_return_7_days,_0:00:00    0.468063
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.54638
#  asset_2_forward_return_7_days,_0:00:00    0.46981
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539919
#  asset_2_forward_return_7_days,_0:00:00    0.463734
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541234
#  asset_2_forward_return_7_days,_0:00:00    0.467431
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543285
#  asset_2_forward_return_7_days,_0:00:00    0.458463
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544411
#  asset_2_forward_return_7_days,_0:00:00    0.468828
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.532842
#  asset_2_forward_return_7_days,_0:00:00    0.471069
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.529448
#  asset_2_forward_return_7_days,_0:00:00    0.464708
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.528729
#  asset_2_forward_return_7_days,_0:00:00    0.477264
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.530859
#  asset_2_forward_return_7_days,_0:00:00    0.470674
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.530995
#  asset_2_forward_return_7_days,_0:00:00    0.464565
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521171
#  asset_2_forward_return_7_days,_0:00:00    0.477442
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.522360
#  asset_2_forward_return_7_days,_0:00:00    0.487949
# ...
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533007
#  asset_2_forward_return_7_days,_0:00:00    0.490889
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.534295
#  asset_2_forward_return_7_days,_0:00:00    0.475532
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536499
#  asset_2_forward_return_7_days,_0:00:00    0.478707
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538484
#  asset_2_forward_return_7_days,_0:00:00    0.478183
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541937
#  asset_2_forward_return_7_days,_0:00:00    0.469779
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533967
#  asset_2_forward_return_7_days,_0:00:00    0.457641
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.524794
#  asset_2_forward_return_7_days,_0:00:00    0.468307
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.523123
#  asset_2_forward_return_7_days,_0:00:00    0.469014
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520823
#  asset_2_forward_return_7_days,_0:00:00    0.460388
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.520273
#  asset_2_forward_return_7_days,_0:00:00    0.454732
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518528
#  asset_2_forward_return_7_days,_0:00:00    0.452511
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521749
#  asset_2_forward_return_7_days,_0:00:00    0.459651
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521477
#  asset_2_forward_return_7_days,_0:00:00    0.462500
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.518384
#  asset_2_forward_return_7_days,_0:00:00    0.462452
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.510977
#  asset_2_forward_return_7_days,_0:00:00    0.469841
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.512146
#  asset_2_forward_return_7_days,_0:00:00    0.466763
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.524145
#  asset_2_forward_return_7_days,_0:00:00    0.463747
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.526137
#  asset_2_forward_return_7_days,_0:00:00    0.458131
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536379
#  asset_2_forward_return_7_days,_0:00:00    0.453833
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.527194
#  asset_2_forward_return_7_days,_0:00:00    0.444517
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535122
#  asset_2_forward_return_7_days,_0:00:00    0.441899
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546062
#  asset_2_forward_return_7_days,_0:00:00    0.442920
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543562
#  asset_2_forward_return_7_days,_0:00:00    0.432460
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548476
#  asset_2_forward_return_7_days,_0:00:00    0.446685
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.559054
#  asset_2_forward_return_7_days,_0:00:00    0.450376
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.558556
#  asset_2_forward_return_7_days,_0:00:00    0.456345
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.54713
#  asset_2_forward_return_7_days,_0:00:00    0.44909
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548900
#  asset_2_forward_return_7_days,_0:00:00    0.436521
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.556423
#  asset_2_forward_return_7_days,_0:00:00    0.429703
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.550854
#  asset_2_forward_return_7_days,_0:00:00    0.437046
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.55713
#  asset_2_forward_return_7_days,_0:00:00    0.43479
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.554318
#  asset_2_forward_return_7_days,_0:00:00    0.446619
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.551383
#  asset_2_forward_return_7_days,_0:00:00    0.462135
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.558804
#  asset_2_forward_return_7_days,_0:00:00    0.448974
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547825
#  asset_2_forward_return_7_days,_0:00:00    0.440338
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549377
#  asset_2_forward_return_7_days,_0:00:00    0.447255
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546335
#  asset_2_forward_return_7_days,_0:00:00    0.451638
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.555897
#  asset_2_forward_return_7_days,_0:00:00    0.448895
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.558907
#  asset_2_forward_return_7_days,_0:00:00    0.454075
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.574019
#  asset_2_forward_return_7_days,_0:00:00    0.459549
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.565230
#  asset_2_forward_return_7_days,_0:00:00    0.449289
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.570218
#  asset_2_forward_return_7_days,_0:00:00    0.438047
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.560655
#  asset_2_forward_return_7_days,_0:00:00    0.445058
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.563512
#  asset_2_forward_return_7_days,_0:00:00    0.437593
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.563561
#  asset_2_forward_return_7_days,_0:00:00    0.440752
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.569180
#  asset_2_forward_return_7_days,_0:00:00    0.433548
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.567916
#  asset_2_forward_return_7_days,_0:00:00    0.432808
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.564034
#  asset_2_forward_return_7_days,_0:00:00    0.421856
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.573068
#  asset_2_forward_return_7_days,_0:00:00    0.427846
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.572398
#  asset_2_forward_return_7_days,_0:00:00    0.421392
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.572373
#  asset_2_forward_return_7_days,_0:00:00    0.424492
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.572034
#  asset_2_forward_return_7_days,_0:00:00    0.431767
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.575443
#  asset_2_forward_return_7_days,_0:00:00    0.427705
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.575432
#  asset_2_forward_return_7_days,_0:00:00    0.428498
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.562553
#  asset_2_forward_return_7_days,_0:00:00    0.426099
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.558457
#  asset_2_forward_return_7_days,_0:00:00    0.436967
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.557445
#  asset_2_forward_return_7_days,_0:00:00    0.438467
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.551655
#  asset_2_forward_return_7_days,_0:00:00    0.443331
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.562578
#  asset_2_forward_return_7_days,_0:00:00    0.450842
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553724
#  asset_2_forward_return_7_days,_0:00:00    0.438974
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553600
#  asset_2_forward_return_7_days,_0:00:00    0.437339
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544327
#  asset_2_forward_return_7_days,_0:00:00    0.449454
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538016
#  asset_2_forward_return_7_days,_0:00:00    0.449562
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.533467
#  asset_2_forward_return_7_days,_0:00:00    0.460654
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536453
#  asset_2_forward_return_7_days,_0:00:00    0.458901
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.544319
#  asset_2_forward_return_7_days,_0:00:00    0.449289
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546309
#  asset_2_forward_return_7_days,_0:00:00    0.451550
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548662
#  asset_2_forward_return_7_days,_0:00:00    0.441725
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.550246
#  asset_2_forward_return_7_days,_0:00:00    0.441956
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553093
#  asset_2_forward_return_7_days,_0:00:00    0.439951
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.557805
#  asset_2_forward_return_7_days,_0:00:00    0.443350
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.550224
#  asset_2_forward_return_7_days,_0:00:00    0.452054
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542017
#  asset_2_forward_return_7_days,_0:00:00    0.459297
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540292
#  asset_2_forward_return_7_days,_0:00:00    0.437475
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.537400
#  asset_2_forward_return_7_days,_0:00:00    0.428384
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.521010
#  asset_2_forward_return_7_days,_0:00:00    0.434603
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.525617
#  asset_2_forward_return_7_days,_0:00:00    0.433627
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.528843
#  asset_2_forward_return_7_days,_0:00:00    0.443447
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541042
#  asset_2_forward_return_7_days,_0:00:00    0.456516
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542955
#  asset_2_forward_return_7_days,_0:00:00    0.463477
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.535434
#  asset_2_forward_return_7_days,_0:00:00    0.473780
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.538753
#  asset_2_forward_return_7_days,_0:00:00    0.475296
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540263
#  asset_2_forward_return_7_days,_0:00:00    0.472613
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536525
#  asset_2_forward_return_7_days,_0:00:00    0.484596
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.556567
#  asset_2_forward_return_7_days,_0:00:00    0.480190
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553864
#  asset_2_forward_return_7_days,_0:00:00    0.476039
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553662
#  asset_2_forward_return_7_days,_0:00:00    0.469793
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.555535
#  asset_2_forward_return_7_days,_0:00:00    0.456301
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.559667
#  asset_2_forward_return_7_days,_0:00:00    0.464808
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548817
#  asset_2_forward_return_7_days,_0:00:00    0.469433
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.542592
#  asset_2_forward_return_7_days,_0:00:00    0.454646
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540074
#  asset_2_forward_return_7_days,_0:00:00    0.455926
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.545912
#  asset_2_forward_return_7_days,_0:00:00    0.454469
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.539776
#  asset_2_forward_return_7_days,_0:00:00    0.462727
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.543110
#  asset_2_forward_return_7_days,_0:00:00    0.471403
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549847
#  asset_2_forward_return_7_days,_0:00:00    0.477629
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546209
#  asset_2_forward_return_7_days,_0:00:00    0.481714
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.554683
#  asset_2_forward_return_7_days,_0:00:00    0.485430
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.552223
#  asset_2_forward_return_7_days,_0:00:00    0.472999
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.559146
#  asset_2_forward_return_7_days,_0:00:00    0.476917
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.555515
#  asset_2_forward_return_7_days,_0:00:00    0.481855
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.555449
#  asset_2_forward_return_7_days,_0:00:00    0.467500
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.567288
#  asset_2_forward_return_7_days,_0:00:00    0.482723
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.563022
#  asset_2_forward_return_7_days,_0:00:00    0.489037
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553729
#  asset_2_forward_return_7_days,_0:00:00    0.488872
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549299
#  asset_2_forward_return_7_days,_0:00:00    0.485525
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546386
#  asset_2_forward_return_7_days,_0:00:00    0.475376
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549810
#  asset_2_forward_return_7_days,_0:00:00    0.490905
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.545992
#  asset_2_forward_return_7_days,_0:00:00    0.485253
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.556579
#  asset_2_forward_return_7_days,_0:00:00    0.467946
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547117
#  asset_2_forward_return_7_days,_0:00:00    0.454708
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.549015
#  asset_2_forward_return_7_days,_0:00:00    0.472094
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.546050
#  asset_2_forward_return_7_days,_0:00:00    0.463796
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553669
#  asset_2_forward_return_7_days,_0:00:00    0.452079
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.559986
#  asset_2_forward_return_7_days,_0:00:00    0.451739
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.568910
#  asset_2_forward_return_7_days,_0:00:00    0.456123
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.573247
#  asset_2_forward_return_7_days,_0:00:00    0.463313
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.572221
#  asset_2_forward_return_7_days,_0:00:00    0.460205
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.561174
#  asset_2_forward_return_7_days,_0:00:00    0.456238
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.553472
#  asset_2_forward_return_7_days,_0:00:00    0.449445
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.558816
#  asset_2_forward_return_7_days,_0:00:00    0.438034
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.557478
#  asset_2_forward_return_7_days,_0:00:00    0.435369
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.559279
#  asset_2_forward_return_7_days,_0:00:00    0.443477
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.556791
#  asset_2_forward_return_7_days,_0:00:00    0.453743
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.560497
#  asset_2_forward_return_7_days,_0:00:00    0.443703
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547973
#  asset_2_forward_return_7_days,_0:00:00    0.454312
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.551285
#  asset_2_forward_return_7_days,_0:00:00    0.456847
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.541462
#  asset_2_forward_return_7_days,_0:00:00    0.445954
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.536085
#  asset_2_forward_return_7_days,_0:00:00    0.451303
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.540257
#  asset_2_forward_return_7_days,_0:00:00    0.443899
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.547263
#  asset_2_forward_return_7_days,_0:00:00    0.450628
#  dtype: float64,
#  asset_1_forward_return_7_days,_0:00:00    0.548537
#  asset_2_forward_return_7_days,_0:00:00    0.457307
#  dtype: float64,
#  ...]

# %% [markdown]
# ## Results
#
# ### The Good
#
# * REINFORCE Converges to the expected portfolio using different reward functions.
# * REINFORCE Convergence is agnostic of estimation of a covariance matrix.
# * REINFORCE Can allow us easily to add extra features to the parametrization of our function ( technical indicators, sentiment indices , etc)
# * REINFORCE finds the optimal policy even when the rewards its stochastic.
#
# ### The Bad
#
# * The speed of convergence is pretty slow. it took around 10+ minutes for convergence. This was expected as REINFORCE algorithm is known for having a high variance.
# * The convergence was achieved by comparing the results with the expected answer. However the L2 Norm of the parametrization vectors continues to bounce even after convergence. model overfit?.
# * The convergence seem to requiry a dynamic $\alpha$ to avoid bouncing out of an optimal result.
# * Naive implementation of SGD cant be paralelized.
#
# ### The Ugly
#
# * REINFORCE is an on-policy method.  This means that is sample-ineficient as we cant use episodes generated by old policies. How can we proove that if the market is action independent then we can reuse episodes?

# %% [markdown]
# ## Next Steps
#
# * Explore REINFORCE with baseline and A2C method.
# * Implement parametrization in TensorFlow to be able to use non linear and stronger optimizaers and paralelization.
