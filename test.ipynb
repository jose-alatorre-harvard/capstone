# %%
import pandas as pd

# %%
df=pd.read_parquet("/home/jose/Downloads/features_df")

# %%
df
# Out:
#                            log_return_VLUE_lag_0  log_return_QUAL_lag_0  \
# time
# 2014-09-10 04:00:00+00:00              -0.005114              -0.005827
# 2014-09-11 04:00:00+00:00               0.001242               0.006159
# 2014-09-12 04:00:00+00:00               0.000000              -0.002991
# 2014-09-15 04:00:00+00:00              -0.006539              -0.004003
# 2014-09-16 04:00:00+00:00               0.001561              -0.002677
# ...                                          ...                    ...
# 2020-11-10 05:00:00+00:00               0.035702               0.023247
# 2020-11-11 05:00:00+00:00               0.013513              -0.001714
# 2020-11-12 05:00:00+00:00              -0.000986               0.003064
# 2020-11-13 05:00:00+00:00              -0.017783              -0.011950
# 2020-11-16 05:00:00+00:00               0.024662               0.015723
#
#                            log_return_MTUM_lag_0  log_return_SIZE_lag_0  \
# time
# ...
